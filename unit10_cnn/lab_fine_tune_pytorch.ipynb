# %% [markdown]
#  # Lab:  Transfer Learning with a Pre-Trained Deep Neural Network
#
# As we discussed earlier, state-of-the-art neural networks involve millions of parameters that are prohibitively difficult to train from scratch.  In this lab, we will illustrate a powerful technique called *fine-tuning* where we start with a large pre-trained network and then re-train only the final layers to adapt to a new task.  The method is also called *transfer learning* and can produce excellent results on very small datasets with very little computational time.
#
# This lab is based partially on this
# [excellent blog](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).  In performing the lab, you will learn to:
# * Build a custom image dataset
# * Fine tune the final layers of an existing deep neural network for a new classification task.
# * Load images with a `DataGenerator`.
#
# The lab has two versions:
# * *CPU version*:  In this version, you use lower resolution images so that the lab can be performed on your laptop.  The resulting accuracy is lower.  The code will also take considerable time to execute.
# * *GPU version*:  This version uses higher resolution images but requires a GPU instance. See the [notes](../GCP/getting_started.md) on setting up a GPU instance on Google Cloud Platform.  The GPU training is much faster (< 1 minute).
#
# **MS students must complete the GPU version** of this lab.

# %% [markdown]
# ## Create a Dataset
#
# In this example, we will try to develop a classifier that can discriminate between two classes:  `cars` and `bicycles`.  One could imagine this type of classifier would be useful in vehicle vision systems.   The first task is to build a dataset.
#
# TODO:  Create training and test datasets with:
# * 1000 training images of cars
# * 1000 training images of bicylces
# * 300 test images of cars
# * 300 test images of bicylces
# * The images don't need to be the same size.  But, you can reduce the resolution if you need to save disk space.
#
# The images should be organized in the following directory structure:
#
#     ./train
#         /car
#            car_0000.jpg
#            car_0001.jpg
#            ...
#            car_0999.jpg
#         /bicycle
#            bicycle_0000.jpg
#            bicycle_0001.jpg
#            ...
#            bicycle_0999.jpg
#     ./test
#         /car
#            car_1001.jpg
#            car_1001.jpg
#            ...
#            car_1299.jpg
#         /bicycle
#            bicycle_1000.jpg
#            bicycle_1001.jpg
#            ...
#            bicycle_1299.jpg
#
# The naming of the files within the directories does not matter.  The `ImageDataGenerator` class below will find the filenames.  Just make sure there are the correct number of files in each directory.
#
# A nice automated way of building such a dataset if through the [FlickrAPI](demo2_flickr_images.ipynb).  Remember that if you run the FlickrAPI twice, it may collect the same images.  So, you need to run it once and split the images into training and test directories.

# %%
import flickrapi
import urllib.request
import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import skimage.transform
import requests
from io import BytesIO
from scipy.ndimage import affine_transform
import os
import warnings

# %matplotlib inline

# %%
api_key = u'9a1d373d19dc05fee6c917f89c5e87f5'
api_secret = u'459c530fd9f16a45'
flickr = flickrapi.FlickrAPI(api_key, api_secret)

# %%
dir_name = ['./train/', './test/']
keyword_name = ['car', 'bicycle']

for dir_n in dir_name:
    for keyword_n in keyword_name:
        
        full_dir = dir_n + keyword_n + '/'

        dir_exists = os.path.isdir(full_dir)
        if not dir_exists:
            os.makedirs(full_dir)
            print("Making directory %s" % full_dir)
        else:
            print("Will store images in directory %s" % full_dir)

# %%
nrow = 150
ncol = 150
for keys in keyword_name:
    photo = flickr.walk(text=keys, tag_mode='all', tags=keys,extras='url_c',\
                     sort='relevance',per_page=100)
    i = 0
    for photo in photo:
        url=photo.get('url_c')
        if not (url is None):

            # Create a file from the URL
            # This may only work in Python3
            response = requests.get(url)
            file = BytesIO(response.content)

            # Read image from file
            im = skimage.io.imread(file)

            # Resize images
            im1 = skimage.transform.resize(im,(nrow,ncol),mode='constant', anti_aliasing=True)

            # Convert to uint8, suppress the warning about the precision loss
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                im2 = skimage.img_as_ubyte(im1)
            if i < 1000:
            # Save the image
                local_name = './train/' + keys + '/' + keys + '_' + '{0:04d}.jpg'.format(i)
            else:
                local_name = './test/' + keys + '/' + keys + '_' + '{0:04d}.jpg'.format(i)
            skimage.io.imsave(local_name, im2)      
            print(local_name)
            i = i + 1       
        if (i >= 1300):        
            break

# %% [markdown]
# ## Loading a Pre-Trained Deep Network
#
# We follow the [VGG16 demo](./vgg16.ipynb) to load a pre-trained deep VGG16 network.  First, run a command to verify your instance is connected to a GPU.
# Now load the appropriate packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset, DataLoader, sampler, SubsetRandomSampler
from torchvision import transforms, utils
import torch.nn.functional as F

USE_GPU = True

dtype = torch.float32 # float or double

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('using device:', device)
# Out:
# using device: cpu

# %%
import torchvision.models as models

# %% [markdown]
# Set the dimensions of the input image.  The sizes below would work on a GPU machine.  But, if you have a CPU image, you can use a smaller image size, like `64 x 64`.
# * It seems to me that nn.AdaptiveAvgPool2d is used in pytorch implement of VGG16, which make the model adaptive to image of any size
#
# Now we follow the [VGG16 demo](./vgg16.ipynb) and load the deep VGG16 network.  Alternatively, you can use any other pre-trained model in keras.  When using the `applications.VGG16` method you will need to:
# * Set `include_top=False` to not include the top layer
# * Set the `image_shape` based on the above dimensions.  Remember, `image_shape` should be height x width x 3 since the images are color.
#
# To create now new model, we create a Sequential model.  Then, loop over the layers in `base_model.layers` and add each layer to the new model.
# * I clip the classification layers in a more flexible way
#
# Next, loop through the layers in `model`, and freeze each layer by setting `layer.trainable = False`.  This way, you will not have to *re-train* any of the existing layers.
#
# Now, add the following layers to `model`:
# * A `Flatten()` layer which reshapes the outputs to a single channel.
# * A fully-connected layer with 256 output units and `relu` activation
# * A final fully-connected layer.  Since this is a binary classification, there should be one output and `sigmoid` activation.
#
# Print the model summary.  This will display the number of trainable parameters vs. the non-trainable parameters.

# %%
# TODO
class Flatten(nn.Module):
    '''
    A Flatten Layer implement from 
    https://gist.github.com/VoVAllen/5531c78a2d3f1ff3df772038bca37a83
    '''
    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        return x.view(x.size(0), -1)

vgg16 = models.vgg16(pretrained=True)

# Freeze the weights in VGG 16
for param in vgg16.parameters():
    param.requires_grad = False

'''
Notes: 

using feature extraction, global average pooling and add classifier to tail of it
Obviously a VGG 16 with 5 maxpool would be too much for our image size, 
we have to promise that at least 7*7 is leftover after 2 pow number of maxpool, this requires at least 224

So I remove the 7*7 adaptive average pool and use a 1*1 global average pool instead
This is a trick ResNet use to reduce image size, and it should be fine interm of performance
'''

# TODO:  Load the VGG16 network
# input_shape = ...
# base_model = applications.VGG16(weights='imagenet', ...)

model = nn.Sequential(vgg16.features,
                    nn.AdaptiveAvgPool2d((1,1)),
                    Flatten(),
                    nn.Linear(512, 512),
                    nn.BatchNorm1d(512),
                    nn.ReLU(inplace=True),
                    nn.Linear(512, 1)
                    )

print(model) # print the model summary

'''
Notes:

print the size of params that to be trained
linear1 w - 512*512
linear1 b - 512
bn mean - 512
bn std - 512
linear2 w - 1*512
linear2 b - 1
'''
for param in model.parameters():
    if param.requires_grad == True:
        print(param.size())
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): AdaptiveAvgPool2d(output_size=(1, 1))
#   (2): Flatten()
#   (3): Linear(in_features=512, out_features=512, bias=True)
#   (4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace)
#   (6): Linear(in_features=512, out_features=1, bias=True)
# )
# torch.Size([512, 512])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# torch.Size([1, 512])
# torch.Size([1])

# %% [markdown]
# ## Using Generators to Load Data
#
# Up to now, the training data has been represented in a large matrix.  This is not possible for image data when the datasets are very large.  For these applications, the `keras` package provides a `ImageDataGenerator` class that can fetch images on the fly from a directory of images.  Using multi-threading, training can be performed on one mini-batch while the image reader can read files for the next mini-batch. The code below creates an `ImageDataGenerator` for the training data.  In addition to the reading the files, the `ImageDataGenerator` creates random deformations of the image to expand the total dataset size.  When the training data is limited, using data augmentation is very important.

# %%
def AffineFun(img, r, xm, ym, order):
    sinx = np.sin(np.deg2rad(r))
    cosx = np.cos(np.deg2rad(r))

    xc = img[0].shape[0]//2
    yc = img[0].shape[1]//2

    Mc = np.array([[1, 0, xc],[0, 1, yc],[0, 0, 1]])
    R = np.array([[cosx, -sinx, 0],[sinx, cosx, 0],[0, 0, 1]])
    Mb = np.array([[1, 0,-xc],[0, 1,-yc],[0, 0, 1]])
    MM = np.array([[1, 0, xm],[0, 1, ym],[0, 0, 1]])

    Matrix = np.linalg.multi_dot([Mc, R, Mb, MM])

    C = img.shape[0]
    for chan in np.arange(C):
        img[chan] = affine_transform(img[chan], Matrix, output_shape=img[chan].shape, order=order)

    return img

def filpFun(img, x):

    if x==True:
        img = np.flip(img, axis=2)

    return img

class RandomFilp(object):
    def __init__(self, p):
        self.p = p

    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        return {'image': filpFun(image, self.p), 'label': label}

class RandomAffine(object):
    def __init__(self, fluR, fluM):

        self.fluR = fluR
        self.fluM = fluM

    def __call__(self, sample):

        r = np.random.uniform(-self.fluR, self.fluR, size=1)
        xm, ym = np.random.uniform(-self.fluM, self.fluM, size=2)

        image, label = sample['image'], sample['label']
        return {'image': AffineFun(image, r, xm, ym, 3), \
                'label': label}

def toTensor(sample):
    image, label = sample['image'], sample['label']
    return {'image': torch.from_numpy(image.copy()),
            'label': torch.from_numpy(label.copy())}

class CBDataset(Dataset):
    """car, bicycle dataset."""

    def __init__(self, transform=None):
        self.transform = transform
        pass
    
    def __len__(self):
        return 2600

    def __getitem__(self, idx):
        # idx \in [0, 2600)
        # car, bicycle in [0, 1299)
        if idx%2 == 0:
            image = skimage.io.imread('./train/car/' + 'car' + '_' + '{0:04d}.jpg'.format(idx//2))
            label = np.array([0])
        else:
            image = skimage.io.imread('./train/bicycle/' + 'bicycle' + '_' + '{0:04d}.jpg'.format(idx//2))
            label = np.array([1])
        
        if image.ndim == 2:
            # black and white
            image = image.reshape(*image.shape, 1)
            image = np.concatenate((image, image, image), axis=2)
        
        image = image.transpose((2,0,1))
        sample = {'image': image, 'label': label}
        
        if self.transform:
            sample = self.transform(sample)
        
        # for showing purpose only, comment after debug
        # plt.imshow(sample['image'].transpose(1, 2, 0))
        # plt.show()
        
        sample = toTensor(sample)

        return sample
    
transformed_dataset = CBDataset(
                        transform=transforms.Compose([
                            RandomFilp(True),
                            RandomAffine(10, 20)
                        ])
                    )

for i in range(len(transformed_dataset)):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['label'].size())

    if i == 2600:
        break
# Out:
# 0 torch.Size([3, 150, 150]) torch.Size([1])
# 1 torch.Size([3, 150, 150]) torch.Size([1])
# 2 torch.Size([3, 150, 150]) torch.Size([1])
# 3 torch.Size([3, 150, 150]) torch.Size([1])
# 4 torch.Size([3, 150, 150]) torch.Size([1])
# 5 torch.Size([3, 150, 150]) torch.Size([1])
# 6 torch.Size([3, 150, 150]) torch.Size([1])
# 7 torch.Size([3, 150, 150]) torch.Size([1])
# 8 torch.Size([3, 150, 150]) torch.Size([1])
# 9 torch.Size([3, 150, 150]) torch.Size([1])
# 10 torch.Size([3, 150, 150]) torch.Size([1])
# 11 torch.Size([3, 150, 150]) torch.Size([1])
# 12 torch.Size([3, 150, 150]) torch.Size([1])
# 13 torch.Size([3, 150, 150]) torch.Size([1])
# 14 torch.Size([3, 150, 150]) torch.Size([1])
# 15 torch.Size([3, 150, 150]) torch.Size([1])
# 16 torch.Size([3, 150, 150]) torch.Size([1])
# 17 torch.Size([3, 150, 150]) torch.Size([1])
# 18 torch.Size([3, 150, 150]) torch.Size([1])
# 19 torch.Size([3, 150, 150]) torch.Size([1])
# 20 torch.Size([3, 150, 150]) torch.Size([1])
# 21 torch.Size([3, 150, 150]) torch.Size([1])
# 22 torch.Size([3, 150, 150]) torch.Size([1])
# 23 torch.Size([3, 150, 150]) torch.Size([1])
# 24 torch.Size([3, 150, 150]) torch.Size([1])
# 25 torch.Size([3, 150, 150]) torch.Size([1])
# 26 torch.Size([3, 150, 150]) torch.Size([1])
# 27 torch.Size([3, 150, 150]) torch.Size([1])
# 28 torch.Size([3, 150, 150]) torch.Size([1])
# 29 torch.Size([3, 150, 150]) torch.Size([1])
# 30 torch.Size([3, 150, 150]) torch.Size([1])
# 31 torch.Size([3, 150, 150]) torch.Size([1])
# 32 torch.Size([3, 150, 150]) torch.Size([1])
# 33 torch.Size([3, 150, 150]) torch.Size([1])
# 34 torch.Size([3, 150, 150]) torch.Size([1])
# 35 torch.Size([3, 150, 150]) torch.Size([1])
# 36 torch.Size([3, 150, 150]) torch.Size([1])
# 37 torch.Size([3, 150, 150]) torch.Size([1])
# 38 torch.Size([3, 150, 150]) torch.Size([1])
# 39 torch.Size([3, 150, 150]) torch.Size([1])
# 40 torch.Size([3, 150, 150]) torch.Size([1])
# 41 torch.Size([3, 150, 150]) torch.Size([1])
# 42 torch.Size([3, 150, 150]) torch.Size([1])
# 43 torch.Size([3, 150, 150]) torch.Size([1])
# 44 torch.Size([3, 150, 150]) torch.Size([1])
# 45 torch.Size([3, 150, 150]) torch.Size([1])
# 46 torch.Size([3, 150, 150]) torch.Size([1])
# 47 torch.Size([3, 150, 150]) torch.Size([1])
# 48 torch.Size([3, 150, 150]) torch.Size([1])
# 49 torch.Size([3, 150, 150]) torch.Size([1])
# 50 torch.Size([3, 150, 150]) torch.Size([1])
# 51 torch.Size([3, 150, 150]) torch.Size([1])
# 52 torch.Size([3, 150, 150]) torch.Size([1])
# 53 torch.Size([3, 150, 150]) torch.Size([1])
# 54 torch.Size([3, 150, 150]) torch.Size([1])
# 55 torch.Size([3, 150, 150]) torch.Size([1])
# 56 torch.Size([3, 150, 150]) torch.Size([1])
# 57 torch.Size([3, 150, 150]) torch.Size([1])
# 58 torch.Size([3, 150, 150]) torch.Size([1])
# 59 torch.Size([3, 150, 150]) torch.Size([1])
# 60 torch.Size([3, 150, 150]) torch.Size([1])
# 61 torch.Size([3, 150, 150]) torch.Size([1])
# 62 torch.Size([3, 150, 150]) torch.Size([1])
# 63 torch.Size([3, 150, 150]) torch.Size([1])
# 64 torch.Size([3, 150, 150]) torch.Size([1])
# 65 torch.Size([3, 150, 150]) torch.Size([1])
# 66 torch.Size([3, 150, 150]) torch.Size([1])
# 67 torch.Size([3, 150, 150]) torch.Size([1])
# 68 torch.Size([3, 150, 150]) torch.Size([1])
# 69 torch.Size([3, 150, 150]) torch.Size([1])
# 70 torch.Size([3, 150, 150]) torch.Size([1])
# 71 torch.Size([3, 150, 150]) torch.Size([1])
# 72 torch.Size([3, 150, 150]) torch.Size([1])
# 73 torch.Size([3, 150, 150]) torch.Size([1])
# 74 torch.Size([3, 150, 150]) torch.Size([1])
# 75 torch.Size([3, 150, 150]) torch.Size([1])
# 76 torch.Size([3, 150, 150]) torch.Size([1])
# 77 torch.Size([3, 150, 150]) torch.Size([1])
# 78 torch.Size([3, 150, 150]) torch.Size([1])
# 79 torch.Size([3, 150, 150]) torch.Size([1])
# 80 torch.Size([3, 150, 150]) torch.Size([1])
# 81 torch.Size([3, 150, 150]) torch.Size([1])
# 82 torch.Size([3, 150, 150]) torch.Size([1])
# 83 torch.Size([3, 150, 150]) torch.Size([1])
# 84 torch.Size([3, 150, 150]) torch.Size([1])
# 85 torch.Size([3, 150, 150]) torch.Size([1])
# 86 torch.Size([3, 150, 150]) torch.Size([1])
# 87 torch.Size([3, 150, 150]) torch.Size([1])
# 88 torch.Size([3, 150, 150]) torch.Size([1])
# 89 torch.Size([3, 150, 150]) torch.Size([1])
# 90 torch.Size([3, 150, 150]) torch.Size([1])
# 91 torch.Size([3, 150, 150]) torch.Size([1])
# 92 torch.Size([3, 150, 150]) torch.Size([1])
# 93 torch.Size([3, 150, 150]) torch.Size([1])
# 94 torch.Size([3, 150, 150]) torch.Size([1])
# 95 torch.Size([3, 150, 150]) torch.Size([1])
# 96 torch.Size([3, 150, 150]) torch.Size([1])
# 97 torch.Size([3, 150, 150]) torch.Size([1])
# 98 torch.Size([3, 150, 150]) torch.Size([1])
# 99 torch.Size([3, 150, 150]) torch.Size([1])
# 100 torch.Size([3, 150, 150]) torch.Size([1])
# 101 torch.Size([3, 150, 150]) torch.Size([1])
# 102 torch.Size([3, 150, 150]) torch.Size([1])
# 103 torch.Size([3, 150, 150]) torch.Size([1])
# 104 torch.Size([3, 150, 150]) torch.Size([1])
# 105 torch.Size([3, 150, 150]) torch.Size([1])
# 106 torch.Size([3, 150, 150]) torch.Size([1])
# 107 torch.Size([3, 150, 150]) torch.Size([1])
# 108 torch.Size([3, 150, 150]) torch.Size([1])
# 109 torch.Size([3, 150, 150]) torch.Size([1])
# 110 torch.Size([3, 150, 150]) torch.Size([1])
# 111 torch.Size([3, 150, 150]) torch.Size([1])
# 112 torch.Size([3, 150, 150]) torch.Size([1])
# 113 torch.Size([3, 150, 150]) torch.Size([1])
# 114 torch.Size([3, 150, 150]) torch.Size([1])
# 115 torch.Size([3, 150, 150]) torch.Size([1])
# 116 torch.Size([3, 150, 150]) torch.Size([1])
# 117 torch.Size([3, 150, 150]) torch.Size([1])
# 118 torch.Size([3, 150, 150]) torch.Size([1])
# 119 torch.Size([3, 150, 150]) torch.Size([1])
# 120 torch.Size([3, 150, 150]) torch.Size([1])
# 121 torch.Size([3, 150, 150]) torch.Size([1])
# 122 torch.Size([3, 150, 150]) torch.Size([1])
# 123 torch.Size([3, 150, 150]) torch.Size([1])
# 124 torch.Size([3, 150, 150]) torch.Size([1])
# 125 torch.Size([3, 150, 150]) torch.Size([1])
# 126 torch.Size([3, 150, 150]) torch.Size([1])
# 127 torch.Size([3, 150, 150]) torch.Size([1])
# 128 torch.Size([3, 150, 150]) torch.Size([1])
# 129 torch.Size([3, 150, 150]) torch.Size([1])
# 130 torch.Size([3, 150, 150]) torch.Size([1])
# 131 torch.Size([3, 150, 150]) torch.Size([1])
# 132 torch.Size([3, 150, 150]) torch.Size([1])
# 133 torch.Size([3, 150, 150]) torch.Size([1])
# 134 torch.Size([3, 150, 150]) torch.Size([1])
# 135 torch.Size([3, 150, 150]) torch.Size([1])
# 136 torch.Size([3, 150, 150]) torch.Size([1])
# 137 torch.Size([3, 150, 150]) torch.Size([1])
# 138 torch.Size([3, 150, 150]) torch.Size([1])
# 139 torch.Size([3, 150, 150]) torch.Size([1])
# 140 torch.Size([3, 150, 150]) torch.Size([1])
# 141 torch.Size([3, 150, 150]) torch.Size([1])
# 142 torch.Size([3, 150, 150]) torch.Size([1])
# 143 torch.Size([3, 150, 150]) torch.Size([1])
# 144 torch.Size([3, 150, 150]) torch.Size([1])
# 145 torch.Size([3, 150, 150]) torch.Size([1])
# 146 torch.Size([3, 150, 150]) torch.Size([1])
# 147 torch.Size([3, 150, 150]) torch.Size([1])
# 148 torch.Size([3, 150, 150]) torch.Size([1])
# 149 torch.Size([3, 150, 150]) torch.Size([1])
# 150 torch.Size([3, 150, 150]) torch.Size([1])
# 151 torch.Size([3, 150, 150]) torch.Size([1])
# 152 torch.Size([3, 150, 150]) torch.Size([1])
# 153 torch.Size([3, 150, 150]) torch.Size([1])
# 154 torch.Size([3, 150, 150]) torch.Size([1])
# 155 torch.Size([3, 150, 150]) torch.Size([1])
# 156 torch.Size([3, 150, 150]) torch.Size([1])
# 157 torch.Size([3, 150, 150]) torch.Size([1])
# 158 torch.Size([3, 150, 150]) torch.Size([1])
# 159 torch.Size([3, 150, 150]) torch.Size([1])
# 160 torch.Size([3, 150, 150]) torch.Size([1])
# 161 torch.Size([3, 150, 150]) torch.Size([1])
# 162 torch.Size([3, 150, 150]) torch.Size([1])
# 163 torch.Size([3, 150, 150]) torch.Size([1])
# 164 torch.Size([3, 150, 150]) torch.Size([1])
# 165 torch.Size([3, 150, 150]) torch.Size([1])
# 166 torch.Size([3, 150, 150]) torch.Size([1])
# 167 torch.Size([3, 150, 150]) torch.Size([1])
# 168 torch.Size([3, 150, 150]) torch.Size([1])
# 169 torch.Size([3, 150, 150]) torch.Size([1])
# 170 torch.Size([3, 150, 150]) torch.Size([1])
# 171 torch.Size([3, 150, 150]) torch.Size([1])
# 172 torch.Size([3, 150, 150]) torch.Size([1])
# 173 torch.Size([3, 150, 150]) torch.Size([1])
# 174 torch.Size([3, 150, 150]) torch.Size([1])
# 175 torch.Size([3, 150, 150]) torch.Size([1])
# 176 torch.Size([3, 150, 150]) torch.Size([1])
# 177 torch.Size([3, 150, 150]) torch.Size([1])
# 178 torch.Size([3, 150, 150]) torch.Size([1])
# 179 torch.Size([3, 150, 150]) torch.Size([1])
# 180 torch.Size([3, 150, 150]) torch.Size([1])
# 181 torch.Size([3, 150, 150]) torch.Size([1])
# 182 torch.Size([3, 150, 150]) torch.Size([1])
# 183 torch.Size([3, 150, 150]) torch.Size([1])
# 184 torch.Size([3, 150, 150]) torch.Size([1])
# 185 torch.Size([3, 150, 150]) torch.Size([1])
# 186 torch.Size([3, 150, 150]) torch.Size([1])
# 187 torch.Size([3, 150, 150]) torch.Size([1])
# 188 torch.Size([3, 150, 150]) torch.Size([1])
# 189 torch.Size([3, 150, 150]) torch.Size([1])
# 190 torch.Size([3, 150, 150]) torch.Size([1])
# 191 torch.Size([3, 150, 150]) torch.Size([1])
# 192 torch.Size([3, 150, 150]) torch.Size([1])
# 193 torch.Size([3, 150, 150]) torch.Size([1])
# 194 torch.Size([3, 150, 150]) torch.Size([1])
# 195 torch.Size([3, 150, 150]) torch.Size([1])
# 196 torch.Size([3, 150, 150]) torch.Size([1])
# 197 torch.Size([3, 150, 150]) torch.Size([1])
# 198 torch.Size([3, 150, 150]) torch.Size([1])
# 199 torch.Size([3, 150, 150]) torch.Size([1])
# 200 torch.Size([3, 150, 150]) torch.Size([1])
# 201 torch.Size([3, 150, 150]) torch.Size([1])
# 202 torch.Size([3, 150, 150]) torch.Size([1])
# 203 torch.Size([3, 150, 150]) torch.Size([1])
# 204 torch.Size([3, 150, 150]) torch.Size([1])
# 205 torch.Size([3, 150, 150]) torch.Size([1])
# 206 torch.Size([3, 150, 150]) torch.Size([1])
# 207 torch.Size([3, 150, 150]) torch.Size([1])
# 208 torch.Size([3, 150, 150]) torch.Size([1])
# 209 torch.Size([3, 150, 150]) torch.Size([1])
# 210 torch.Size([3, 150, 150]) torch.Size([1])
# 211 torch.Size([3, 150, 150]) torch.Size([1])
# 212 torch.Size([3, 150, 150]) torch.Size([1])
# 213 torch.Size([3, 150, 150]) torch.Size([1])
# 214 torch.Size([3, 150, 150]) torch.Size([1])
# 215 torch.Size([3, 150, 150]) torch.Size([1])
# 216 torch.Size([3, 150, 150]) torch.Size([1])
# 217 torch.Size([3, 150, 150]) torch.Size([1])
# 218 torch.Size([3, 150, 150]) torch.Size([1])
# 219 torch.Size([3, 150, 150]) torch.Size([1])
# 220 torch.Size([3, 150, 150]) torch.Size([1])
# 221 torch.Size([3, 150, 150]) torch.Size([1])
# 222 torch.Size([3, 150, 150]) torch.Size([1])
# 223 torch.Size([3, 150, 150]) torch.Size([1])
# 224 torch.Size([3, 150, 150]) torch.Size([1])
# 225 torch.Size([3, 150, 150]) torch.Size([1])
# 226 torch.Size([3, 150, 150]) torch.Size([1])
# 227 torch.Size([3, 150, 150]) torch.Size([1])
# 228 torch.Size([3, 150, 150]) torch.Size([1])
# 229 torch.Size([3, 150, 150]) torch.Size([1])
# 230 torch.Size([3, 150, 150]) torch.Size([1])
# 231 torch.Size([3, 150, 150]) torch.Size([1])
# 232 torch.Size([3, 150, 150]) torch.Size([1])
# 233 torch.Size([3, 150, 150]) torch.Size([1])
# 234 torch.Size([3, 150, 150]) torch.Size([1])
# 235 torch.Size([3, 150, 150]) torch.Size([1])
# 236 torch.Size([3, 150, 150]) torch.Size([1])
# 237 torch.Size([3, 150, 150]) torch.Size([1])
# 238 torch.Size([3, 150, 150]) torch.Size([1])
# 239 torch.Size([3, 150, 150]) torch.Size([1])
# 240 torch.Size([3, 150, 150]) torch.Size([1])
# 241 torch.Size([3, 150, 150]) torch.Size([1])
# 242 torch.Size([3, 150, 150]) torch.Size([1])
# 243 torch.Size([3, 150, 150]) torch.Size([1])
# 244 torch.Size([3, 150, 150]) torch.Size([1])
# 245 torch.Size([3, 150, 150]) torch.Size([1])
# 246 torch.Size([3, 150, 150]) torch.Size([1])
# 247 torch.Size([3, 150, 150]) torch.Size([1])
# 248 torch.Size([3, 150, 150]) torch.Size([1])
# 249 torch.Size([3, 150, 150]) torch.Size([1])
# 250 torch.Size([3, 150, 150]) torch.Size([1])
# 251 torch.Size([3, 150, 150]) torch.Size([1])
# 252 torch.Size([3, 150, 150]) torch.Size([1])
# 253 torch.Size([3, 150, 150]) torch.Size([1])
# 254 torch.Size([3, 150, 150]) torch.Size([1])
# 255 torch.Size([3, 150, 150]) torch.Size([1])
# 256 torch.Size([3, 150, 150]) torch.Size([1])
# 257 torch.Size([3, 150, 150]) torch.Size([1])
# 258 torch.Size([3, 150, 150]) torch.Size([1])
# 259 torch.Size([3, 150, 150]) torch.Size([1])
# 260 torch.Size([3, 150, 150]) torch.Size([1])
# 261 torch.Size([3, 150, 150]) torch.Size([1])
# 262 torch.Size([3, 150, 150]) torch.Size([1])
# 263 torch.Size([3, 150, 150]) torch.Size([1])
# 264 torch.Size([3, 150, 150]) torch.Size([1])
# 265 torch.Size([3, 150, 150]) torch.Size([1])
# 266 torch.Size([3, 150, 150]) torch.Size([1])
# 267 torch.Size([3, 150, 150]) torch.Size([1])
# 268 torch.Size([3, 150, 150]) torch.Size([1])
# 269 torch.Size([3, 150, 150]) torch.Size([1])
# 270 torch.Size([3, 150, 150]) torch.Size([1])
# 271 torch.Size([3, 150, 150]) torch.Size([1])
# 272 torch.Size([3, 150, 150]) torch.Size([1])
# 273 torch.Size([3, 150, 150]) torch.Size([1])
# 274 torch.Size([3, 150, 150]) torch.Size([1])
# 275 torch.Size([3, 150, 150]) torch.Size([1])
# 276 torch.Size([3, 150, 150]) torch.Size([1])
# 277 torch.Size([3, 150, 150]) torch.Size([1])
# 278 torch.Size([3, 150, 150]) torch.Size([1])
# 279 torch.Size([3, 150, 150]) torch.Size([1])
# 280 torch.Size([3, 150, 150]) torch.Size([1])
# 281 torch.Size([3, 150, 150]) torch.Size([1])
# 282 torch.Size([3, 150, 150]) torch.Size([1])
# 283 torch.Size([3, 150, 150]) torch.Size([1])
# 284 torch.Size([3, 150, 150]) torch.Size([1])
# 285 torch.Size([3, 150, 150]) torch.Size([1])
# 286 torch.Size([3, 150, 150]) torch.Size([1])
# 287 torch.Size([3, 150, 150]) torch.Size([1])
# 288 torch.Size([3, 150, 150]) torch.Size([1])
# 289 torch.Size([3, 150, 150]) torch.Size([1])
# 290 torch.Size([3, 150, 150]) torch.Size([1])
# 291 torch.Size([3, 150, 150]) torch.Size([1])
# 292 torch.Size([3, 150, 150]) torch.Size([1])
# 293 torch.Size([3, 150, 150]) torch.Size([1])
# 294 torch.Size([3, 150, 150]) torch.Size([1])
# 295 torch.Size([3, 150, 150]) torch.Size([1])
# 296 torch.Size([3, 150, 150]) torch.Size([1])
# 297 torch.Size([3, 150, 150]) torch.Size([1])
# 298 torch.Size([3, 150, 150]) torch.Size([1])
# 299 torch.Size([3, 150, 150]) torch.Size([1])
# 300 torch.Size([3, 150, 150]) torch.Size([1])
# 301 torch.Size([3, 150, 150]) torch.Size([1])
# 302 torch.Size([3, 150, 150]) torch.Size([1])
# 303 torch.Size([3, 150, 150]) torch.Size([1])
# 304 torch.Size([3, 150, 150]) torch.Size([1])
# 305 torch.Size([3, 150, 150]) torch.Size([1])
# 306 torch.Size([3, 150, 150]) torch.Size([1])
# 307 torch.Size([3, 150, 150]) torch.Size([1])
# 308 torch.Size([3, 150, 150]) torch.Size([1])
# 309 torch.Size([3, 150, 150]) torch.Size([1])
# 310 torch.Size([3, 150, 150]) torch.Size([1])
# 311 torch.Size([3, 150, 150]) torch.Size([1])
# 312 torch.Size([3, 150, 150]) torch.Size([1])
# 313 torch.Size([3, 150, 150]) torch.Size([1])
# 314 torch.Size([3, 150, 150]) torch.Size([1])
# 315 torch.Size([3, 150, 150]) torch.Size([1])
# 316 torch.Size([3, 150, 150]) torch.Size([1])
# 317 torch.Size([3, 150, 150]) torch.Size([1])
# 318 torch.Size([3, 150, 150]) torch.Size([1])
# 319 torch.Size([3, 150, 150]) torch.Size([1])
# 320 torch.Size([3, 150, 150]) torch.Size([1])
# 321 torch.Size([3, 150, 150]) torch.Size([1])
# 322 torch.Size([3, 150, 150]) torch.Size([1])
# 323 torch.Size([3, 150, 150]) torch.Size([1])
# 324 torch.Size([3, 150, 150]) torch.Size([1])
# 325 torch.Size([3, 150, 150]) torch.Size([1])
# 326 torch.Size([3, 150, 150]) torch.Size([1])
# 327 torch.Size([3, 150, 150]) torch.Size([1])
# 328 torch.Size([3, 150, 150]) torch.Size([1])
# 329 torch.Size([3, 150, 150]) torch.Size([1])
# 330 torch.Size([3, 150, 150]) torch.Size([1])
# 331 torch.Size([3, 150, 150]) torch.Size([1])
# 332 torch.Size([3, 150, 150]) torch.Size([1])
# 333 torch.Size([3, 150, 150]) torch.Size([1])
# 334 torch.Size([3, 150, 150]) torch.Size([1])
# 335 torch.Size([3, 150, 150]) torch.Size([1])
# 336 torch.Size([3, 150, 150]) torch.Size([1])
# 337 torch.Size([3, 150, 150]) torch.Size([1])
# 338 torch.Size([3, 150, 150]) torch.Size([1])
# 339 torch.Size([3, 150, 150]) torch.Size([1])
# 340 torch.Size([3, 150, 150]) torch.Size([1])
# 341 torch.Size([3, 150, 150]) torch.Size([1])
# 342 torch.Size([3, 150, 150]) torch.Size([1])
# 343 torch.Size([3, 150, 150]) torch.Size([1])
# 344 torch.Size([3, 150, 150]) torch.Size([1])
# 345 torch.Size([3, 150, 150]) torch.Size([1])
# 346 torch.Size([3, 150, 150]) torch.Size([1])
# 347 torch.Size([3, 150, 150]) torch.Size([1])
# 348 torch.Size([3, 150, 150]) torch.Size([1])
# 349 torch.Size([3, 150, 150]) torch.Size([1])
# 350 torch.Size([3, 150, 150]) torch.Size([1])
# 351 torch.Size([3, 150, 150]) torch.Size([1])
# 352 torch.Size([3, 150, 150]) torch.Size([1])
# 353 torch.Size([3, 150, 150]) torch.Size([1])
# 354 torch.Size([3, 150, 150]) torch.Size([1])
# 355 torch.Size([3, 150, 150]) torch.Size([1])
# 356 torch.Size([3, 150, 150]) torch.Size([1])
# 357 torch.Size([3, 150, 150]) torch.Size([1])
# 358 torch.Size([3, 150, 150]) torch.Size([1])
# 359 torch.Size([3, 150, 150]) torch.Size([1])
# 360 torch.Size([3, 150, 150]) torch.Size([1])
# 361 torch.Size([3, 150, 150]) torch.Size([1])
# 362 torch.Size([3, 150, 150]) torch.Size([1])
# 363 torch.Size([3, 150, 150]) torch.Size([1])
# 364 torch.Size([3, 150, 150]) torch.Size([1])
# 365 torch.Size([3, 150, 150]) torch.Size([1])
# 366 torch.Size([3, 150, 150]) torch.Size([1])
# 367 torch.Size([3, 150, 150]) torch.Size([1])
# 368 torch.Size([3, 150, 150]) torch.Size([1])
# 369 torch.Size([3, 150, 150]) torch.Size([1])
# 370 torch.Size([3, 150, 150]) torch.Size([1])
# 371 torch.Size([3, 150, 150]) torch.Size([1])
# 372 torch.Size([3, 150, 150]) torch.Size([1])
# 373 torch.Size([3, 150, 150]) torch.Size([1])
# 374 torch.Size([3, 150, 150]) torch.Size([1])
# 375 torch.Size([3, 150, 150]) torch.Size([1])
# 376 torch.Size([3, 150, 150]) torch.Size([1])
# 377 torch.Size([3, 150, 150]) torch.Size([1])
# 378 torch.Size([3, 150, 150]) torch.Size([1])
# 379 torch.Size([3, 150, 150]) torch.Size([1])
# 380 torch.Size([3, 150, 150]) torch.Size([1])
# 381 torch.Size([3, 150, 150]) torch.Size([1])
# 382 torch.Size([3, 150, 150]) torch.Size([1])
# 383 torch.Size([3, 150, 150]) torch.Size([1])
# 384 torch.Size([3, 150, 150]) torch.Size([1])
# 385 torch.Size([3, 150, 150]) torch.Size([1])
# 386 torch.Size([3, 150, 150]) torch.Size([1])
# 387 torch.Size([3, 150, 150]) torch.Size([1])
# 388 torch.Size([3, 150, 150]) torch.Size([1])
# 389 torch.Size([3, 150, 150]) torch.Size([1])
# 390 torch.Size([3, 150, 150]) torch.Size([1])
# 391 torch.Size([3, 150, 150]) torch.Size([1])
# 392 torch.Size([3, 150, 150]) torch.Size([1])
# 393 torch.Size([3, 150, 150]) torch.Size([1])
# 394 torch.Size([3, 150, 150]) torch.Size([1])
# 395 torch.Size([3, 150, 150]) torch.Size([1])
# 396 torch.Size([3, 150, 150]) torch.Size([1])
# 397 torch.Size([3, 150, 150]) torch.Size([1])
# 398 torch.Size([3, 150, 150]) torch.Size([1])
# 399 torch.Size([3, 150, 150]) torch.Size([1])
# 400 torch.Size([3, 150, 150]) torch.Size([1])
# 401 torch.Size([3, 150, 150]) torch.Size([1])
# 402 torch.Size([3, 150, 150]) torch.Size([1])
# 403 torch.Size([3, 150, 150]) torch.Size([1])
# 404 torch.Size([3, 150, 150]) torch.Size([1])
# 405 torch.Size([3, 150, 150]) torch.Size([1])
# 406 torch.Size([3, 150, 150]) torch.Size([1])
# 407 torch.Size([3, 150, 150]) torch.Size([1])
# 408 torch.Size([3, 150, 150]) torch.Size([1])
# 409 torch.Size([3, 150, 150]) torch.Size([1])
# 410 torch.Size([3, 150, 150]) torch.Size([1])
# 411 torch.Size([3, 150, 150]) torch.Size([1])
# 412 torch.Size([3, 150, 150]) torch.Size([1])
# 413 torch.Size([3, 150, 150]) torch.Size([1])
# 414 torch.Size([3, 150, 150]) torch.Size([1])
# 415 torch.Size([3, 150, 150]) torch.Size([1])
# 416 torch.Size([3, 150, 150]) torch.Size([1])
# 417 torch.Size([3, 150, 150]) torch.Size([1])
# 418 torch.Size([3, 150, 150]) torch.Size([1])
# 419 torch.Size([3, 150, 150]) torch.Size([1])
# 420 torch.Size([3, 150, 150]) torch.Size([1])
# 421 torch.Size([3, 150, 150]) torch.Size([1])
# 422 torch.Size([3, 150, 150]) torch.Size([1])
# 423 torch.Size([3, 150, 150]) torch.Size([1])
# 424 torch.Size([3, 150, 150]) torch.Size([1])
# 425 torch.Size([3, 150, 150]) torch.Size([1])
# 426 torch.Size([3, 150, 150]) torch.Size([1])
# 427 torch.Size([3, 150, 150]) torch.Size([1])
# 428 torch.Size([3, 150, 150]) torch.Size([1])
# 429 torch.Size([3, 150, 150]) torch.Size([1])
# 430 torch.Size([3, 150, 150]) torch.Size([1])
# 431 torch.Size([3, 150, 150]) torch.Size([1])
# 432 torch.Size([3, 150, 150]) torch.Size([1])
# 433 torch.Size([3, 150, 150]) torch.Size([1])
# 434 torch.Size([3, 150, 150]) torch.Size([1])
# 435 torch.Size([3, 150, 150]) torch.Size([1])
# 436 torch.Size([3, 150, 150]) torch.Size([1])
# 437 torch.Size([3, 150, 150]) torch.Size([1])
# 438 torch.Size([3, 150, 150]) torch.Size([1])
# 439 torch.Size([3, 150, 150]) torch.Size([1])
# 440 torch.Size([3, 150, 150]) torch.Size([1])
# 441 torch.Size([3, 150, 150]) torch.Size([1])
# 442 torch.Size([3, 150, 150]) torch.Size([1])
# 443 torch.Size([3, 150, 150]) torch.Size([1])
# 444 torch.Size([3, 150, 150]) torch.Size([1])
# 445 torch.Size([3, 150, 150]) torch.Size([1])
# 446 torch.Size([3, 150, 150]) torch.Size([1])
# 447 torch.Size([3, 150, 150]) torch.Size([1])
# 448 torch.Size([3, 150, 150]) torch.Size([1])
# 449 torch.Size([3, 150, 150]) torch.Size([1])
# 450 torch.Size([3, 150, 150]) torch.Size([1])
# 451 torch.Size([3, 150, 150]) torch.Size([1])
# 452 torch.Size([3, 150, 150]) torch.Size([1])
# 453 torch.Size([3, 150, 150]) torch.Size([1])
# 454 torch.Size([3, 150, 150]) torch.Size([1])
# 455 torch.Size([3, 150, 150]) torch.Size([1])
# 456 torch.Size([3, 150, 150]) torch.Size([1])
# 457 torch.Size([3, 150, 150]) torch.Size([1])
# 458 torch.Size([3, 150, 150]) torch.Size([1])
# 459 torch.Size([3, 150, 150]) torch.Size([1])
# 460 torch.Size([3, 150, 150]) torch.Size([1])
# 461 torch.Size([3, 150, 150]) torch.Size([1])
# 462 torch.Size([3, 150, 150]) torch.Size([1])
# 463 torch.Size([3, 150, 150]) torch.Size([1])
# 464 torch.Size([3, 150, 150]) torch.Size([1])
# 465 torch.Size([3, 150, 150]) torch.Size([1])
# 466 torch.Size([3, 150, 150]) torch.Size([1])
# 467 torch.Size([3, 150, 150]) torch.Size([1])
# 468 torch.Size([3, 150, 150]) torch.Size([1])
# 469 torch.Size([3, 150, 150]) torch.Size([1])
# 470 torch.Size([3, 150, 150]) torch.Size([1])
# 471 torch.Size([3, 150, 150]) torch.Size([1])
# 472 torch.Size([3, 150, 150]) torch.Size([1])
# 473 torch.Size([3, 150, 150]) torch.Size([1])
# 474 torch.Size([3, 150, 150]) torch.Size([1])
# 475 torch.Size([3, 150, 150]) torch.Size([1])
# 476 torch.Size([3, 150, 150]) torch.Size([1])
# 477 torch.Size([3, 150, 150]) torch.Size([1])
# 478 torch.Size([3, 150, 150]) torch.Size([1])
# 479 torch.Size([3, 150, 150]) torch.Size([1])
# 480 torch.Size([3, 150, 150]) torch.Size([1])
# 481 torch.Size([3, 150, 150]) torch.Size([1])
# 482 torch.Size([3, 150, 150]) torch.Size([1])
# 483 torch.Size([3, 150, 150]) torch.Size([1])
# 484 torch.Size([3, 150, 150]) torch.Size([1])
# 485 torch.Size([3, 150, 150]) torch.Size([1])
# 486 torch.Size([3, 150, 150]) torch.Size([1])
# 487 torch.Size([3, 150, 150]) torch.Size([1])
# 488 torch.Size([3, 150, 150]) torch.Size([1])
# 489 torch.Size([3, 150, 150]) torch.Size([1])
# 490 torch.Size([3, 150, 150]) torch.Size([1])
# 491 torch.Size([3, 150, 150]) torch.Size([1])
# 492 torch.Size([3, 150, 150]) torch.Size([1])
# 493 torch.Size([3, 150, 150]) torch.Size([1])
# 494 torch.Size([3, 150, 150]) torch.Size([1])
# 495 torch.Size([3, 150, 150]) torch.Size([1])
# 496 torch.Size([3, 150, 150]) torch.Size([1])
# 497 torch.Size([3, 150, 150]) torch.Size([1])
# 498 torch.Size([3, 150, 150]) torch.Size([1])
# 499 torch.Size([3, 150, 150]) torch.Size([1])
# 500 torch.Size([3, 150, 150]) torch.Size([1])
# 501 torch.Size([3, 150, 150]) torch.Size([1])
# 502 torch.Size([3, 150, 150]) torch.Size([1])
# 503 torch.Size([3, 150, 150]) torch.Size([1])
# 504 torch.Size([3, 150, 150]) torch.Size([1])
# 505 torch.Size([3, 150, 150]) torch.Size([1])
# 506 torch.Size([3, 150, 150]) torch.Size([1])
# 507 torch.Size([3, 150, 150]) torch.Size([1])
# 508 torch.Size([3, 150, 150]) torch.Size([1])
# 509 torch.Size([3, 150, 150]) torch.Size([1])
# 510 torch.Size([3, 150, 150]) torch.Size([1])
# 511 torch.Size([3, 150, 150]) torch.Size([1])
# 512 torch.Size([3, 150, 150]) torch.Size([1])
# 513 torch.Size([3, 150, 150]) torch.Size([1])
# 514 torch.Size([3, 150, 150]) torch.Size([1])
# 515 torch.Size([3, 150, 150]) torch.Size([1])
# 516 torch.Size([3, 150, 150]) torch.Size([1])
# 517 torch.Size([3, 150, 150]) torch.Size([1])
# 518 torch.Size([3, 150, 150]) torch.Size([1])
# 519 torch.Size([3, 150, 150]) torch.Size([1])
# 520 torch.Size([3, 150, 150]) torch.Size([1])
# 521 torch.Size([3, 150, 150]) torch.Size([1])
# 522 torch.Size([3, 150, 150]) torch.Size([1])
# 523 torch.Size([3, 150, 150]) torch.Size([1])
# 524 torch.Size([3, 150, 150]) torch.Size([1])
# 525 torch.Size([3, 150, 150]) torch.Size([1])
# 526 torch.Size([3, 150, 150]) torch.Size([1])
# 527 torch.Size([3, 150, 150]) torch.Size([1])
# 528 torch.Size([3, 150, 150]) torch.Size([1])
# 529 torch.Size([3, 150, 150]) torch.Size([1])
# 530 torch.Size([3, 150, 150]) torch.Size([1])
# 531 torch.Size([3, 150, 150]) torch.Size([1])
# 532 torch.Size([3, 150, 150]) torch.Size([1])
# 533 torch.Size([3, 150, 150]) torch.Size([1])
# 534 torch.Size([3, 150, 150]) torch.Size([1])
# 535 torch.Size([3, 150, 150]) torch.Size([1])
# 536 torch.Size([3, 150, 150]) torch.Size([1])
# 537 torch.Size([3, 150, 150]) torch.Size([1])
# 538 torch.Size([3, 150, 150]) torch.Size([1])
# 539 torch.Size([3, 150, 150]) torch.Size([1])
# 540 torch.Size([3, 150, 150]) torch.Size([1])
# 541 torch.Size([3, 150, 150]) torch.Size([1])
# 542 torch.Size([3, 150, 150]) torch.Size([1])
# 543 torch.Size([3, 150, 150]) torch.Size([1])
# 544 torch.Size([3, 150, 150]) torch.Size([1])
# 545 torch.Size([3, 150, 150]) torch.Size([1])
# 546 torch.Size([3, 150, 150]) torch.Size([1])
# 547 torch.Size([3, 150, 150]) torch.Size([1])
# 548 torch.Size([3, 150, 150]) torch.Size([1])
# 549 torch.Size([3, 150, 150]) torch.Size([1])
# 550 torch.Size([3, 150, 150]) torch.Size([1])
# 551 torch.Size([3, 150, 150]) torch.Size([1])
# 552 torch.Size([3, 150, 150]) torch.Size([1])
# 553 torch.Size([3, 150, 150]) torch.Size([1])
# 554 torch.Size([3, 150, 150]) torch.Size([1])
# 555 torch.Size([3, 150, 150]) torch.Size([1])
# 556 torch.Size([3, 150, 150]) torch.Size([1])
# 557 torch.Size([3, 150, 150]) torch.Size([1])
# 558 torch.Size([3, 150, 150]) torch.Size([1])
# 559 torch.Size([3, 150, 150]) torch.Size([1])
# 560 torch.Size([3, 150, 150]) torch.Size([1])
# 561 torch.Size([3, 150, 150]) torch.Size([1])
# 562 torch.Size([3, 150, 150]) torch.Size([1])
# 563 torch.Size([3, 150, 150]) torch.Size([1])
# 564 torch.Size([3, 150, 150]) torch.Size([1])
# 565 torch.Size([3, 150, 150]) torch.Size([1])
# 566 torch.Size([3, 150, 150]) torch.Size([1])
# 567 torch.Size([3, 150, 150]) torch.Size([1])
# 568 torch.Size([3, 150, 150]) torch.Size([1])
# 569 torch.Size([3, 150, 150]) torch.Size([1])
# 570 torch.Size([3, 150, 150]) torch.Size([1])
# 571 torch.Size([3, 150, 150]) torch.Size([1])
# 572 torch.Size([3, 150, 150]) torch.Size([1])
# 573 torch.Size([3, 150, 150]) torch.Size([1])
# 574 torch.Size([3, 150, 150]) torch.Size([1])
# 575 torch.Size([3, 150, 150]) torch.Size([1])
# 576 torch.Size([3, 150, 150]) torch.Size([1])
# 577 torch.Size([3, 150, 150]) torch.Size([1])
# 578 torch.Size([3, 150, 150]) torch.Size([1])
# 579 torch.Size([3, 150, 150]) torch.Size([1])
# 580 torch.Size([3, 150, 150]) torch.Size([1])
# 581 torch.Size([3, 150, 150]) torch.Size([1])
# 582 torch.Size([3, 150, 150]) torch.Size([1])
# 583 torch.Size([3, 150, 150]) torch.Size([1])
# 584 torch.Size([3, 150, 150]) torch.Size([1])
# 585 torch.Size([3, 150, 150]) torch.Size([1])
# 586 torch.Size([3, 150, 150]) torch.Size([1])
# 587 torch.Size([3, 150, 150]) torch.Size([1])
# 588 torch.Size([3, 150, 150]) torch.Size([1])
# 589 torch.Size([3, 150, 150]) torch.Size([1])
# 590 torch.Size([3, 150, 150]) torch.Size([1])
# 591 torch.Size([3, 150, 150]) torch.Size([1])
# 592 torch.Size([3, 150, 150]) torch.Size([1])
# 593 torch.Size([3, 150, 150]) torch.Size([1])
# 594 torch.Size([3, 150, 150]) torch.Size([1])
# 595 torch.Size([3, 150, 150]) torch.Size([1])
# 596 torch.Size([3, 150, 150]) torch.Size([1])
# 597 torch.Size([3, 150, 150]) torch.Size([1])
# 598 torch.Size([3, 150, 150]) torch.Size([1])
# 599 torch.Size([3, 150, 150]) torch.Size([1])
# 600 torch.Size([3, 150, 150]) torch.Size([1])
# 601 torch.Size([3, 150, 150]) torch.Size([1])
# 602 torch.Size([3, 150, 150]) torch.Size([1])
# 603 torch.Size([3, 150, 150]) torch.Size([1])
# 604 torch.Size([3, 150, 150]) torch.Size([1])
# 605 torch.Size([3, 150, 150]) torch.Size([1])
# 606 torch.Size([3, 150, 150]) torch.Size([1])
# 607 torch.Size([3, 150, 150]) torch.Size([1])
# 608 torch.Size([3, 150, 150]) torch.Size([1])
# 609 torch.Size([3, 150, 150]) torch.Size([1])
# 610 torch.Size([3, 150, 150]) torch.Size([1])
# 611 torch.Size([3, 150, 150]) torch.Size([1])
# 612 torch.Size([3, 150, 150]) torch.Size([1])
# 613 torch.Size([3, 150, 150]) torch.Size([1])
# 614 torch.Size([3, 150, 150]) torch.Size([1])
# 615 torch.Size([3, 150, 150]) torch.Size([1])
# 616 torch.Size([3, 150, 150]) torch.Size([1])
# 617 torch.Size([3, 150, 150]) torch.Size([1])
# 618 torch.Size([3, 150, 150]) torch.Size([1])
# 619 torch.Size([3, 150, 150]) torch.Size([1])
# 620 torch.Size([3, 150, 150]) torch.Size([1])
# 621 torch.Size([3, 150, 150]) torch.Size([1])
# 622 torch.Size([3, 150, 150]) torch.Size([1])
# 623 torch.Size([3, 150, 150]) torch.Size([1])
# 624 torch.Size([3, 150, 150]) torch.Size([1])
# 625 torch.Size([3, 150, 150]) torch.Size([1])
# 626 torch.Size([3, 150, 150]) torch.Size([1])
# 627 torch.Size([3, 150, 150]) torch.Size([1])
# 628 torch.Size([3, 150, 150]) torch.Size([1])
# 629 torch.Size([3, 150, 150]) torch.Size([1])
# 630 torch.Size([3, 150, 150]) torch.Size([1])
# 631 torch.Size([3, 150, 150]) torch.Size([1])
# 632 torch.Size([3, 150, 150]) torch.Size([1])
# 633 torch.Size([3, 150, 150]) torch.Size([1])
# 634 torch.Size([3, 150, 150]) torch.Size([1])
# 635 torch.Size([3, 150, 150]) torch.Size([1])
# 636 torch.Size([3, 150, 150]) torch.Size([1])
# 637 torch.Size([3, 150, 150]) torch.Size([1])
# 638 torch.Size([3, 150, 150]) torch.Size([1])
# 639 torch.Size([3, 150, 150]) torch.Size([1])
# 640 torch.Size([3, 150, 150]) torch.Size([1])
# 641 torch.Size([3, 150, 150]) torch.Size([1])
# 642 torch.Size([3, 150, 150]) torch.Size([1])
# 643 torch.Size([3, 150, 150]) torch.Size([1])
# 644 torch.Size([3, 150, 150]) torch.Size([1])
# 645 torch.Size([3, 150, 150]) torch.Size([1])
# 646 torch.Size([3, 150, 150]) torch.Size([1])
# 647 torch.Size([3, 150, 150]) torch.Size([1])
# 648 torch.Size([3, 150, 150]) torch.Size([1])
# 649 torch.Size([3, 150, 150]) torch.Size([1])
# 650 torch.Size([3, 150, 150]) torch.Size([1])
# 651 torch.Size([3, 150, 150]) torch.Size([1])
# 652 torch.Size([3, 150, 150]) torch.Size([1])
# 653 torch.Size([3, 150, 150]) torch.Size([1])
# 654 torch.Size([3, 150, 150]) torch.Size([1])
# 655 torch.Size([3, 150, 150]) torch.Size([1])
# 656 torch.Size([3, 150, 150]) torch.Size([1])
# 657 torch.Size([3, 150, 150]) torch.Size([1])
# 658 torch.Size([3, 150, 150]) torch.Size([1])
# 659 torch.Size([3, 150, 150]) torch.Size([1])
# 660 torch.Size([3, 150, 150]) torch.Size([1])
# 661 torch.Size([3, 150, 150]) torch.Size([1])
# 662 torch.Size([3, 150, 150]) torch.Size([1])
# 663 torch.Size([3, 150, 150]) torch.Size([1])
# 664 torch.Size([3, 150, 150]) torch.Size([1])
# 665 torch.Size([3, 150, 150]) torch.Size([1])
# 666 torch.Size([3, 150, 150]) torch.Size([1])
# 667 torch.Size([3, 150, 150]) torch.Size([1])
# 668 torch.Size([3, 150, 150]) torch.Size([1])
# 669 torch.Size([3, 150, 150]) torch.Size([1])
# 670 torch.Size([3, 150, 150]) torch.Size([1])
# 671 torch.Size([3, 150, 150]) torch.Size([1])
# 672 torch.Size([3, 150, 150]) torch.Size([1])
# 673 torch.Size([3, 150, 150]) torch.Size([1])
# 674 torch.Size([3, 150, 150]) torch.Size([1])
# 675 torch.Size([3, 150, 150]) torch.Size([1])
# 676 torch.Size([3, 150, 150]) torch.Size([1])
# 677 torch.Size([3, 150, 150]) torch.Size([1])
# 678 torch.Size([3, 150, 150]) torch.Size([1])
# 679 torch.Size([3, 150, 150]) torch.Size([1])
# 680 torch.Size([3, 150, 150]) torch.Size([1])
# 681 torch.Size([3, 150, 150]) torch.Size([1])
# 682 torch.Size([3, 150, 150]) torch.Size([1])
# 683 torch.Size([3, 150, 150]) torch.Size([1])
# 684 torch.Size([3, 150, 150]) torch.Size([1])
# 685 torch.Size([3, 150, 150]) torch.Size([1])
# 686 torch.Size([3, 150, 150]) torch.Size([1])
# 687 torch.Size([3, 150, 150]) torch.Size([1])
# 688 torch.Size([3, 150, 150]) torch.Size([1])
# 689 torch.Size([3, 150, 150]) torch.Size([1])
# 690 torch.Size([3, 150, 150]) torch.Size([1])
# 691 torch.Size([3, 150, 150]) torch.Size([1])
# 692 torch.Size([3, 150, 150]) torch.Size([1])
# 693 torch.Size([3, 150, 150]) torch.Size([1])
# 694 torch.Size([3, 150, 150]) torch.Size([1])
# 695 torch.Size([3, 150, 150]) torch.Size([1])
# 696 torch.Size([3, 150, 150]) torch.Size([1])
# 697 torch.Size([3, 150, 150]) torch.Size([1])
# 698 torch.Size([3, 150, 150]) torch.Size([1])
# 699 torch.Size([3, 150, 150]) torch.Size([1])
# 700 torch.Size([3, 150, 150]) torch.Size([1])
# 701 torch.Size([3, 150, 150]) torch.Size([1])
# 702 torch.Size([3, 150, 150]) torch.Size([1])
# 703 torch.Size([3, 150, 150]) torch.Size([1])
# 704 torch.Size([3, 150, 150]) torch.Size([1])
# 705 torch.Size([3, 150, 150]) torch.Size([1])
# 706 torch.Size([3, 150, 150]) torch.Size([1])
# 707 torch.Size([3, 150, 150]) torch.Size([1])
# 708 torch.Size([3, 150, 150]) torch.Size([1])
# 709 torch.Size([3, 150, 150]) torch.Size([1])
# 710 torch.Size([3, 150, 150]) torch.Size([1])
# 711 torch.Size([3, 150, 150]) torch.Size([1])
# 712 torch.Size([3, 150, 150]) torch.Size([1])
# 713 torch.Size([3, 150, 150]) torch.Size([1])
# 714 torch.Size([3, 150, 150]) torch.Size([1])
# 715 torch.Size([3, 150, 150]) torch.Size([1])
# 716 torch.Size([3, 150, 150]) torch.Size([1])
# 717 torch.Size([3, 150, 150]) torch.Size([1])
# 718 torch.Size([3, 150, 150]) torch.Size([1])
# 719 torch.Size([3, 150, 150]) torch.Size([1])
# 720 torch.Size([3, 150, 150]) torch.Size([1])
# 721 torch.Size([3, 150, 150]) torch.Size([1])
# 722 torch.Size([3, 150, 150]) torch.Size([1])
# 723 torch.Size([3, 150, 150]) torch.Size([1])
# 724 torch.Size([3, 150, 150]) torch.Size([1])
# 725 torch.Size([3, 150, 150]) torch.Size([1])
# 726 torch.Size([3, 150, 150]) torch.Size([1])
# 727 torch.Size([3, 150, 150]) torch.Size([1])
# 728 torch.Size([3, 150, 150]) torch.Size([1])
# 729 torch.Size([3, 150, 150]) torch.Size([1])
# 730 torch.Size([3, 150, 150]) torch.Size([1])
# 731 torch.Size([3, 150, 150]) torch.Size([1])
# 732 torch.Size([3, 150, 150]) torch.Size([1])
# 733 torch.Size([3, 150, 150]) torch.Size([1])
# 734 torch.Size([3, 150, 150]) torch.Size([1])
# 735 torch.Size([3, 150, 150]) torch.Size([1])
# 736 torch.Size([3, 150, 150]) torch.Size([1])
# 737 torch.Size([3, 150, 150]) torch.Size([1])
# 738 torch.Size([3, 150, 150]) torch.Size([1])
# 739 torch.Size([3, 150, 150]) torch.Size([1])
# 740 torch.Size([3, 150, 150]) torch.Size([1])
# 741 torch.Size([3, 150, 150]) torch.Size([1])
# 742 torch.Size([3, 150, 150]) torch.Size([1])
# 743 torch.Size([3, 150, 150]) torch.Size([1])
# 744 torch.Size([3, 150, 150]) torch.Size([1])
# 745 torch.Size([3, 150, 150]) torch.Size([1])
# 746 torch.Size([3, 150, 150]) torch.Size([1])
# 747 torch.Size([3, 150, 150]) torch.Size([1])
# 748 torch.Size([3, 150, 150]) torch.Size([1])
# 749 torch.Size([3, 150, 150]) torch.Size([1])
# 750 torch.Size([3, 150, 150]) torch.Size([1])
# 751 torch.Size([3, 150, 150]) torch.Size([1])
# 752 torch.Size([3, 150, 150]) torch.Size([1])
# 753 torch.Size([3, 150, 150]) torch.Size([1])
# 754 torch.Size([3, 150, 150]) torch.Size([1])
# 755 torch.Size([3, 150, 150]) torch.Size([1])
# 756 torch.Size([3, 150, 150]) torch.Size([1])
# 757 torch.Size([3, 150, 150]) torch.Size([1])
# 758 torch.Size([3, 150, 150]) torch.Size([1])
# 759 torch.Size([3, 150, 150]) torch.Size([1])
# 760 torch.Size([3, 150, 150]) torch.Size([1])
# 761 torch.Size([3, 150, 150]) torch.Size([1])
# 762 torch.Size([3, 150, 150]) torch.Size([1])
# 763 torch.Size([3, 150, 150]) torch.Size([1])
# 764 torch.Size([3, 150, 150]) torch.Size([1])
# 765 torch.Size([3, 150, 150]) torch.Size([1])
# 766 torch.Size([3, 150, 150]) torch.Size([1])
# 767 torch.Size([3, 150, 150]) torch.Size([1])
# 768 torch.Size([3, 150, 150]) torch.Size([1])
# 769 torch.Size([3, 150, 150]) torch.Size([1])
# 770 torch.Size([3, 150, 150]) torch.Size([1])
# 771 torch.Size([3, 150, 150]) torch.Size([1])
# 772 torch.Size([3, 150, 150]) torch.Size([1])
# 773 torch.Size([3, 150, 150]) torch.Size([1])
# 774 torch.Size([3, 150, 150]) torch.Size([1])
# 775 torch.Size([3, 150, 150]) torch.Size([1])
# 776 torch.Size([3, 150, 150]) torch.Size([1])
# 777 torch.Size([3, 150, 150]) torch.Size([1])
# 778 torch.Size([3, 150, 150]) torch.Size([1])
# 779 torch.Size([3, 150, 150]) torch.Size([1])
# 780 torch.Size([3, 150, 150]) torch.Size([1])
# 781 torch.Size([3, 150, 150]) torch.Size([1])
# 782 torch.Size([3, 150, 150]) torch.Size([1])
# 783 torch.Size([3, 150, 150]) torch.Size([1])
# 784 torch.Size([3, 150, 150]) torch.Size([1])
# 785 torch.Size([3, 150, 150]) torch.Size([1])
# 786 torch.Size([3, 150, 150]) torch.Size([1])
# 787 torch.Size([3, 150, 150]) torch.Size([1])
# 788 torch.Size([3, 150, 150]) torch.Size([1])
# 789 torch.Size([3, 150, 150]) torch.Size([1])
# 790 torch.Size([3, 150, 150]) torch.Size([1])
# 791 torch.Size([3, 150, 150]) torch.Size([1])
# 792 torch.Size([3, 150, 150]) torch.Size([1])
# 793 torch.Size([3, 150, 150]) torch.Size([1])
# 794 torch.Size([3, 150, 150]) torch.Size([1])
# 795 torch.Size([3, 150, 150]) torch.Size([1])
# 796 torch.Size([3, 150, 150]) torch.Size([1])
# 797 torch.Size([3, 150, 150]) torch.Size([1])
# 798 torch.Size([3, 150, 150]) torch.Size([1])
# 799 torch.Size([3, 150, 150]) torch.Size([1])
# 800 torch.Size([3, 150, 150]) torch.Size([1])
# 801 torch.Size([3, 150, 150]) torch.Size([1])
# 802 torch.Size([3, 150, 150]) torch.Size([1])
# 803 torch.Size([3, 150, 150]) torch.Size([1])
# 804 torch.Size([3, 150, 150]) torch.Size([1])
# 805 torch.Size([3, 150, 150]) torch.Size([1])
# 806 torch.Size([3, 150, 150]) torch.Size([1])
# 807 torch.Size([3, 150, 150]) torch.Size([1])
# 808 torch.Size([3, 150, 150]) torch.Size([1])
# 809 torch.Size([3, 150, 150]) torch.Size([1])
# 810 torch.Size([3, 150, 150]) torch.Size([1])
# 811 torch.Size([3, 150, 150]) torch.Size([1])
# 812 torch.Size([3, 150, 150]) torch.Size([1])
# 813 torch.Size([3, 150, 150]) torch.Size([1])
# 814 torch.Size([3, 150, 150]) torch.Size([1])
# 815 torch.Size([3, 150, 150]) torch.Size([1])
# 816 torch.Size([3, 150, 150]) torch.Size([1])
# 817 torch.Size([3, 150, 150]) torch.Size([1])
# 818 torch.Size([3, 150, 150]) torch.Size([1])
# 819 torch.Size([3, 150, 150]) torch.Size([1])
# 820 torch.Size([3, 150, 150]) torch.Size([1])
# 821 torch.Size([3, 150, 150]) torch.Size([1])
# 822 torch.Size([3, 150, 150]) torch.Size([1])
# 823 torch.Size([3, 150, 150]) torch.Size([1])
# 824 torch.Size([3, 150, 150]) torch.Size([1])
# 825 torch.Size([3, 150, 150]) torch.Size([1])
# 826 torch.Size([3, 150, 150]) torch.Size([1])
# 827 torch.Size([3, 150, 150]) torch.Size([1])
# 828 torch.Size([3, 150, 150]) torch.Size([1])
# 829 torch.Size([3, 150, 150]) torch.Size([1])
# 830 torch.Size([3, 150, 150]) torch.Size([1])
# 831 torch.Size([3, 150, 150]) torch.Size([1])
# 832 torch.Size([3, 150, 150]) torch.Size([1])
# 833 torch.Size([3, 150, 150]) torch.Size([1])
# 834 torch.Size([3, 150, 150]) torch.Size([1])
# 835 torch.Size([3, 150, 150]) torch.Size([1])
# 836 torch.Size([3, 150, 150]) torch.Size([1])
# 837 torch.Size([3, 150, 150]) torch.Size([1])
# 838 torch.Size([3, 150, 150]) torch.Size([1])
# 839 torch.Size([3, 150, 150]) torch.Size([1])
# 840 torch.Size([3, 150, 150]) torch.Size([1])
# 841 torch.Size([3, 150, 150]) torch.Size([1])
# 842 torch.Size([3, 150, 150]) torch.Size([1])
# 843 torch.Size([3, 150, 150]) torch.Size([1])
# 844 torch.Size([3, 150, 150]) torch.Size([1])
# 845 torch.Size([3, 150, 150]) torch.Size([1])
# 846 torch.Size([3, 150, 150]) torch.Size([1])
# 847 torch.Size([3, 150, 150]) torch.Size([1])
# 848 torch.Size([3, 150, 150]) torch.Size([1])
# 849 torch.Size([3, 150, 150]) torch.Size([1])
# 850 torch.Size([3, 150, 150]) torch.Size([1])
# 851 torch.Size([3, 150, 150]) torch.Size([1])
# 852 torch.Size([3, 150, 150]) torch.Size([1])
# 853 torch.Size([3, 150, 150]) torch.Size([1])
# 854 torch.Size([3, 150, 150]) torch.Size([1])
# 855 torch.Size([3, 150, 150]) torch.Size([1])
# 856 torch.Size([3, 150, 150]) torch.Size([1])
# 857 torch.Size([3, 150, 150]) torch.Size([1])
# 858 torch.Size([3, 150, 150]) torch.Size([1])
# 859 torch.Size([3, 150, 150]) torch.Size([1])
# 860 torch.Size([3, 150, 150]) torch.Size([1])
# 861 torch.Size([3, 150, 150]) torch.Size([1])
# 862 torch.Size([3, 150, 150]) torch.Size([1])
# 863 torch.Size([3, 150, 150]) torch.Size([1])
# 864 torch.Size([3, 150, 150]) torch.Size([1])
# 865 torch.Size([3, 150, 150]) torch.Size([1])
# 866 torch.Size([3, 150, 150]) torch.Size([1])
# 867 torch.Size([3, 150, 150]) torch.Size([1])
# 868 torch.Size([3, 150, 150]) torch.Size([1])
# 869 torch.Size([3, 150, 150]) torch.Size([1])
# 870 torch.Size([3, 150, 150]) torch.Size([1])
# 871 torch.Size([3, 150, 150]) torch.Size([1])
# 872 torch.Size([3, 150, 150]) torch.Size([1])
# 873 torch.Size([3, 150, 150]) torch.Size([1])
# 874 torch.Size([3, 150, 150]) torch.Size([1])
# 875 torch.Size([3, 150, 150]) torch.Size([1])
# 876 torch.Size([3, 150, 150]) torch.Size([1])
# 877 torch.Size([3, 150, 150]) torch.Size([1])
# 878 torch.Size([3, 150, 150]) torch.Size([1])
# 879 torch.Size([3, 150, 150]) torch.Size([1])
# 880 torch.Size([3, 150, 150]) torch.Size([1])
# 881 torch.Size([3, 150, 150]) torch.Size([1])
# 882 torch.Size([3, 150, 150]) torch.Size([1])
# 883 torch.Size([3, 150, 150]) torch.Size([1])
# 884 torch.Size([3, 150, 150]) torch.Size([1])
# 885 torch.Size([3, 150, 150]) torch.Size([1])
# 886 torch.Size([3, 150, 150]) torch.Size([1])
# 887 torch.Size([3, 150, 150]) torch.Size([1])
# 888 torch.Size([3, 150, 150]) torch.Size([1])
# 889 torch.Size([3, 150, 150]) torch.Size([1])
# 890 torch.Size([3, 150, 150]) torch.Size([1])
# 891 torch.Size([3, 150, 150]) torch.Size([1])
# 892 torch.Size([3, 150, 150]) torch.Size([1])
# 893 torch.Size([3, 150, 150]) torch.Size([1])
# 894 torch.Size([3, 150, 150]) torch.Size([1])
# 895 torch.Size([3, 150, 150]) torch.Size([1])
# 896 torch.Size([3, 150, 150]) torch.Size([1])
# 897 torch.Size([3, 150, 150]) torch.Size([1])
# 898 torch.Size([3, 150, 150]) torch.Size([1])
# 899 torch.Size([3, 150, 150]) torch.Size([1])
# 900 torch.Size([3, 150, 150]) torch.Size([1])
# 901 torch.Size([3, 150, 150]) torch.Size([1])
# 902 torch.Size([3, 150, 150]) torch.Size([1])
# 903 torch.Size([3, 150, 150]) torch.Size([1])
# 904 torch.Size([3, 150, 150]) torch.Size([1])
# 905 torch.Size([3, 150, 150]) torch.Size([1])
# 906 torch.Size([3, 150, 150]) torch.Size([1])
# 907 torch.Size([3, 150, 150]) torch.Size([1])
# 908 torch.Size([3, 150, 150]) torch.Size([1])
# 909 torch.Size([3, 150, 150]) torch.Size([1])
# 910 torch.Size([3, 150, 150]) torch.Size([1])
# 911 torch.Size([3, 150, 150]) torch.Size([1])
# 912 torch.Size([3, 150, 150]) torch.Size([1])
# 913 torch.Size([3, 150, 150]) torch.Size([1])
# 914 torch.Size([3, 150, 150]) torch.Size([1])
# 915 torch.Size([3, 150, 150]) torch.Size([1])
# 916 torch.Size([3, 150, 150]) torch.Size([1])
# 917 torch.Size([3, 150, 150]) torch.Size([1])
# 918 torch.Size([3, 150, 150]) torch.Size([1])
# 919 torch.Size([3, 150, 150]) torch.Size([1])
# 920 torch.Size([3, 150, 150]) torch.Size([1])
# 921 torch.Size([3, 150, 150]) torch.Size([1])
# 922 torch.Size([3, 150, 150]) torch.Size([1])
# 923 torch.Size([3, 150, 150]) torch.Size([1])
# 924 torch.Size([3, 150, 150]) torch.Size([1])
# 925 torch.Size([3, 150, 150]) torch.Size([1])
# 926 torch.Size([3, 150, 150]) torch.Size([1])
# 927 torch.Size([3, 150, 150]) torch.Size([1])
# 928 torch.Size([3, 150, 150]) torch.Size([1])
# 929 torch.Size([3, 150, 150]) torch.Size([1])
# 930 torch.Size([3, 150, 150]) torch.Size([1])
# 931 torch.Size([3, 150, 150]) torch.Size([1])
# 932 torch.Size([3, 150, 150]) torch.Size([1])
# 933 torch.Size([3, 150, 150]) torch.Size([1])
# 934 torch.Size([3, 150, 150]) torch.Size([1])
# 935 torch.Size([3, 150, 150]) torch.Size([1])
# 936 torch.Size([3, 150, 150]) torch.Size([1])
# 937 torch.Size([3, 150, 150]) torch.Size([1])
# 938 torch.Size([3, 150, 150]) torch.Size([1])
# 939 torch.Size([3, 150, 150]) torch.Size([1])
# 940 torch.Size([3, 150, 150]) torch.Size([1])
# 941 torch.Size([3, 150, 150]) torch.Size([1])
# 942 torch.Size([3, 150, 150]) torch.Size([1])
# 943 torch.Size([3, 150, 150]) torch.Size([1])
# 944 torch.Size([3, 150, 150]) torch.Size([1])
# 945 torch.Size([3, 150, 150]) torch.Size([1])
# 946 torch.Size([3, 150, 150]) torch.Size([1])
# 947 torch.Size([3, 150, 150]) torch.Size([1])
# 948 torch.Size([3, 150, 150]) torch.Size([1])
# 949 torch.Size([3, 150, 150]) torch.Size([1])
# 950 torch.Size([3, 150, 150]) torch.Size([1])
# 951 torch.Size([3, 150, 150]) torch.Size([1])
# 952 torch.Size([3, 150, 150]) torch.Size([1])
# 953 torch.Size([3, 150, 150]) torch.Size([1])
# 954 torch.Size([3, 150, 150]) torch.Size([1])
# 955 torch.Size([3, 150, 150]) torch.Size([1])
# 956 torch.Size([3, 150, 150]) torch.Size([1])
# 957 torch.Size([3, 150, 150]) torch.Size([1])
# 958 torch.Size([3, 150, 150]) torch.Size([1])
# 959 torch.Size([3, 150, 150]) torch.Size([1])
# 960 torch.Size([3, 150, 150]) torch.Size([1])
# 961 torch.Size([3, 150, 150]) torch.Size([1])
# 962 torch.Size([3, 150, 150]) torch.Size([1])
# 963 torch.Size([3, 150, 150]) torch.Size([1])
# 964 torch.Size([3, 150, 150]) torch.Size([1])
# 965 torch.Size([3, 150, 150]) torch.Size([1])
# 966 torch.Size([3, 150, 150]) torch.Size([1])
# 967 torch.Size([3, 150, 150]) torch.Size([1])
# 968 torch.Size([3, 150, 150]) torch.Size([1])
# 969 torch.Size([3, 150, 150]) torch.Size([1])
# 970 torch.Size([3, 150, 150]) torch.Size([1])
# 971 torch.Size([3, 150, 150]) torch.Size([1])
# 972 torch.Size([3, 150, 150]) torch.Size([1])
# 973 torch.Size([3, 150, 150]) torch.Size([1])
# 974 torch.Size([3, 150, 150]) torch.Size([1])
# 975 torch.Size([3, 150, 150]) torch.Size([1])
# 976 torch.Size([3, 150, 150]) torch.Size([1])
# 977 torch.Size([3, 150, 150]) torch.Size([1])
# 978 torch.Size([3, 150, 150]) torch.Size([1])
# 979 torch.Size([3, 150, 150]) torch.Size([1])
# 980 torch.Size([3, 150, 150]) torch.Size([1])
# 981 torch.Size([3, 150, 150]) torch.Size([1])
# 982 torch.Size([3, 150, 150]) torch.Size([1])
# 983 torch.Size([3, 150, 150]) torch.Size([1])
# 984 torch.Size([3, 150, 150]) torch.Size([1])
# 985 torch.Size([3, 150, 150]) torch.Size([1])
# 986 torch.Size([3, 150, 150]) torch.Size([1])
# 987 torch.Size([3, 150, 150]) torch.Size([1])
# 988 torch.Size([3, 150, 150]) torch.Size([1])
# 989 torch.Size([3, 150, 150]) torch.Size([1])
# 990 torch.Size([3, 150, 150]) torch.Size([1])
# 991 torch.Size([3, 150, 150]) torch.Size([1])
# 992 torch.Size([3, 150, 150]) torch.Size([1])
# 993 torch.Size([3, 150, 150]) torch.Size([1])
# 994 torch.Size([3, 150, 150]) torch.Size([1])
# 995 torch.Size([3, 150, 150]) torch.Size([1])
# 996 torch.Size([3, 150, 150]) torch.Size([1])
# 997 torch.Size([3, 150, 150]) torch.Size([1])
# 998 torch.Size([3, 150, 150]) torch.Size([1])
# 999 torch.Size([3, 150, 150]) torch.Size([1])
# 1000 torch.Size([3, 150, 150]) torch.Size([1])
# 1001 torch.Size([3, 150, 150]) torch.Size([1])
# 1002 torch.Size([3, 150, 150]) torch.Size([1])
# 1003 torch.Size([3, 150, 150]) torch.Size([1])
# 1004 torch.Size([3, 150, 150]) torch.Size([1])
# 1005 torch.Size([3, 150, 150]) torch.Size([1])
# 1006 torch.Size([3, 150, 150]) torch.Size([1])
# 1007 torch.Size([3, 150, 150]) torch.Size([1])
# 1008 torch.Size([3, 150, 150]) torch.Size([1])
# 1009 torch.Size([3, 150, 150]) torch.Size([1])
# 1010 torch.Size([3, 150, 150]) torch.Size([1])
# 1011 torch.Size([3, 150, 150]) torch.Size([1])
# 1012 torch.Size([3, 150, 150]) torch.Size([1])
# 1013 torch.Size([3, 150, 150]) torch.Size([1])
# 1014 torch.Size([3, 150, 150]) torch.Size([1])
# 1015 torch.Size([3, 150, 150]) torch.Size([1])
# 1016 torch.Size([3, 150, 150]) torch.Size([1])
# 1017 torch.Size([3, 150, 150]) torch.Size([1])
# 1018 torch.Size([3, 150, 150]) torch.Size([1])
# 1019 torch.Size([3, 150, 150]) torch.Size([1])
# 1020 torch.Size([3, 150, 150]) torch.Size([1])
# 1021 torch.Size([3, 150, 150]) torch.Size([1])
# 1022 torch.Size([3, 150, 150]) torch.Size([1])
# 1023 torch.Size([3, 150, 150]) torch.Size([1])
# 1024 torch.Size([3, 150, 150]) torch.Size([1])
# 1025 torch.Size([3, 150, 150]) torch.Size([1])
# 1026 torch.Size([3, 150, 150]) torch.Size([1])
# 1027 torch.Size([3, 150, 150]) torch.Size([1])
# 1028 torch.Size([3, 150, 150]) torch.Size([1])
# 1029 torch.Size([3, 150, 150]) torch.Size([1])
# 1030 torch.Size([3, 150, 150]) torch.Size([1])
# 1031 torch.Size([3, 150, 150]) torch.Size([1])
# 1032 torch.Size([3, 150, 150]) torch.Size([1])
# 1033 torch.Size([3, 150, 150]) torch.Size([1])
# 1034 torch.Size([3, 150, 150]) torch.Size([1])
# 1035 torch.Size([3, 150, 150]) torch.Size([1])
# 1036 torch.Size([3, 150, 150]) torch.Size([1])
# 1037 torch.Size([3, 150, 150]) torch.Size([1])
# 1038 torch.Size([3, 150, 150]) torch.Size([1])
# 1039 torch.Size([3, 150, 150]) torch.Size([1])
# 1040 torch.Size([3, 150, 150]) torch.Size([1])
# 1041 torch.Size([3, 150, 150]) torch.Size([1])
# 1042 torch.Size([3, 150, 150]) torch.Size([1])
# 1043 torch.Size([3, 150, 150]) torch.Size([1])
# ...
# 1877 torch.Size([3, 150, 150]) torch.Size([1])
# 1878 torch.Size([3, 150, 150]) torch.Size([1])
# 1879 torch.Size([3, 150, 150]) torch.Size([1])
# 1880 torch.Size([3, 150, 150]) torch.Size([1])
# 1881 torch.Size([3, 150, 150]) torch.Size([1])
# 1882 torch.Size([3, 150, 150]) torch.Size([1])
# 1883 torch.Size([3, 150, 150]) torch.Size([1])
# 1884 torch.Size([3, 150, 150]) torch.Size([1])
# 1885 torch.Size([3, 150, 150]) torch.Size([1])
# 1886 torch.Size([3, 150, 150]) torch.Size([1])
# 1887 torch.Size([3, 150, 150]) torch.Size([1])
# 1888 torch.Size([3, 150, 150]) torch.Size([1])
# 1889 torch.Size([3, 150, 150]) torch.Size([1])
# 1890 torch.Size([3, 150, 150]) torch.Size([1])
# 1891 torch.Size([3, 150, 150]) torch.Size([1])
# 1892 torch.Size([3, 150, 150]) torch.Size([1])
# 1893 torch.Size([3, 150, 150]) torch.Size([1])
# 1894 torch.Size([3, 150, 150]) torch.Size([1])
# 1895 torch.Size([3, 150, 150]) torch.Size([1])
# 1896 torch.Size([3, 150, 150]) torch.Size([1])
# 1897 torch.Size([3, 150, 150]) torch.Size([1])
# 1898 torch.Size([3, 150, 150]) torch.Size([1])
# 1899 torch.Size([3, 150, 150]) torch.Size([1])
# 1900 torch.Size([3, 150, 150]) torch.Size([1])
# 1901 torch.Size([3, 150, 150]) torch.Size([1])
# 1902 torch.Size([3, 150, 150]) torch.Size([1])
# 1903 torch.Size([3, 150, 150]) torch.Size([1])
# 1904 torch.Size([3, 150, 150]) torch.Size([1])
# 1905 torch.Size([3, 150, 150]) torch.Size([1])
# 1906 torch.Size([3, 150, 150]) torch.Size([1])
# 1907 torch.Size([3, 150, 150]) torch.Size([1])
# 1908 torch.Size([3, 150, 150]) torch.Size([1])
# 1909 torch.Size([3, 150, 150]) torch.Size([1])
# 1910 torch.Size([3, 150, 150]) torch.Size([1])
# 1911 torch.Size([3, 150, 150]) torch.Size([1])
# 1912 torch.Size([3, 150, 150]) torch.Size([1])
# 1913 torch.Size([3, 150, 150]) torch.Size([1])
# 1914 torch.Size([3, 150, 150]) torch.Size([1])
# 1915 torch.Size([3, 150, 150]) torch.Size([1])
# 1916 torch.Size([3, 150, 150]) torch.Size([1])
# 1917 torch.Size([3, 150, 150]) torch.Size([1])
# 1918 torch.Size([3, 150, 150]) torch.Size([1])
# 1919 torch.Size([3, 150, 150]) torch.Size([1])
# 1920 torch.Size([3, 150, 150]) torch.Size([1])
# 1921 torch.Size([3, 150, 150]) torch.Size([1])
# 1922 torch.Size([3, 150, 150]) torch.Size([1])
# 1923 torch.Size([3, 150, 150]) torch.Size([1])
# 1924 torch.Size([3, 150, 150]) torch.Size([1])
# 1925 torch.Size([3, 150, 150]) torch.Size([1])
# 1926 torch.Size([3, 150, 150]) torch.Size([1])
# 1927 torch.Size([3, 150, 150]) torch.Size([1])
# 1928 torch.Size([3, 150, 150]) torch.Size([1])
# 1929 torch.Size([3, 150, 150]) torch.Size([1])
# 1930 torch.Size([3, 150, 150]) torch.Size([1])
# 1931 torch.Size([3, 150, 150]) torch.Size([1])
# 1932 torch.Size([3, 150, 150]) torch.Size([1])
# 1933 torch.Size([3, 150, 150]) torch.Size([1])
# 1934 torch.Size([3, 150, 150]) torch.Size([1])
# 1935 torch.Size([3, 150, 150]) torch.Size([1])
# 1936 torch.Size([3, 150, 150]) torch.Size([1])
# 1937 torch.Size([3, 150, 150]) torch.Size([1])
# 1938 torch.Size([3, 150, 150]) torch.Size([1])
# 1939 torch.Size([3, 150, 150]) torch.Size([1])
# 1940 torch.Size([3, 150, 150]) torch.Size([1])
# 1941 torch.Size([3, 150, 150]) torch.Size([1])
# 1942 torch.Size([3, 150, 150]) torch.Size([1])
# 1943 torch.Size([3, 150, 150]) torch.Size([1])
# 1944 torch.Size([3, 150, 150]) torch.Size([1])
# 1945 torch.Size([3, 150, 150]) torch.Size([1])
# 1946 torch.Size([3, 150, 150]) torch.Size([1])
# 1947 torch.Size([3, 150, 150]) torch.Size([1])
# 1948 torch.Size([3, 150, 150]) torch.Size([1])
# 1949 torch.Size([3, 150, 150]) torch.Size([1])
# 1950 torch.Size([3, 150, 150]) torch.Size([1])
# 1951 torch.Size([3, 150, 150]) torch.Size([1])
# 1952 torch.Size([3, 150, 150]) torch.Size([1])
# 1953 torch.Size([3, 150, 150]) torch.Size([1])
# 1954 torch.Size([3, 150, 150]) torch.Size([1])
# 1955 torch.Size([3, 150, 150]) torch.Size([1])
# 1956 torch.Size([3, 150, 150]) torch.Size([1])
# 1957 torch.Size([3, 150, 150]) torch.Size([1])
# 1958 torch.Size([3, 150, 150]) torch.Size([1])
# 1959 torch.Size([3, 150, 150]) torch.Size([1])
# 1960 torch.Size([3, 150, 150]) torch.Size([1])
# 1961 torch.Size([3, 150, 150]) torch.Size([1])
# 1962 torch.Size([3, 150, 150]) torch.Size([1])
# 1963 torch.Size([3, 150, 150]) torch.Size([1])
# 1964 torch.Size([3, 150, 150]) torch.Size([1])
# 1965 torch.Size([3, 150, 150]) torch.Size([1])
# 1966 torch.Size([3, 150, 150]) torch.Size([1])
# 1967 torch.Size([3, 150, 150]) torch.Size([1])
# 1968 torch.Size([3, 150, 150]) torch.Size([1])
# 1969 torch.Size([3, 150, 150]) torch.Size([1])
# 1970 torch.Size([3, 150, 150]) torch.Size([1])
# 1971 torch.Size([3, 150, 150]) torch.Size([1])
# 1972 torch.Size([3, 150, 150]) torch.Size([1])
# 1973 torch.Size([3, 150, 150]) torch.Size([1])
# 1974 torch.Size([3, 150, 150]) torch.Size([1])
# 1975 torch.Size([3, 150, 150]) torch.Size([1])
# 1976 torch.Size([3, 150, 150]) torch.Size([1])
# 1977 torch.Size([3, 150, 150]) torch.Size([1])
# 1978 torch.Size([3, 150, 150]) torch.Size([1])
# 1979 torch.Size([3, 150, 150]) torch.Size([1])
# 1980 torch.Size([3, 150, 150]) torch.Size([1])
# 1981 torch.Size([3, 150, 150]) torch.Size([1])
# 1982 torch.Size([3, 150, 150]) torch.Size([1])
# 1983 torch.Size([3, 150, 150]) torch.Size([1])
# 1984 torch.Size([3, 150, 150]) torch.Size([1])
# 1985 torch.Size([3, 150, 150]) torch.Size([1])
# 1986 torch.Size([3, 150, 150]) torch.Size([1])
# 1987 torch.Size([3, 150, 150]) torch.Size([1])
# 1988 torch.Size([3, 150, 150]) torch.Size([1])
# 1989 torch.Size([3, 150, 150]) torch.Size([1])
# 1990 torch.Size([3, 150, 150]) torch.Size([1])
# 1991 torch.Size([3, 150, 150]) torch.Size([1])
# 1992 torch.Size([3, 150, 150]) torch.Size([1])
# 1993 torch.Size([3, 150, 150]) torch.Size([1])
# 1994 torch.Size([3, 150, 150]) torch.Size([1])
# 1995 torch.Size([3, 150, 150]) torch.Size([1])
# 1996 torch.Size([3, 150, 150]) torch.Size([1])
# 1997 torch.Size([3, 150, 150]) torch.Size([1])
# 1998 torch.Size([3, 150, 150]) torch.Size([1])
# 1999 torch.Size([3, 150, 150]) torch.Size([1])
# 2000 torch.Size([3, 150, 150]) torch.Size([1])
# 2001 torch.Size([3, 150, 150]) torch.Size([1])
# 2002 torch.Size([3, 150, 150]) torch.Size([1])
# 2003 torch.Size([3, 150, 150]) torch.Size([1])
# 2004 torch.Size([3, 150, 150]) torch.Size([1])
# 2005 torch.Size([3, 150, 150]) torch.Size([1])
# 2006 torch.Size([3, 150, 150]) torch.Size([1])
# 2007 torch.Size([3, 150, 150]) torch.Size([1])
# 2008 torch.Size([3, 150, 150]) torch.Size([1])
# 2009 torch.Size([3, 150, 150]) torch.Size([1])
# 2010 torch.Size([3, 150, 150]) torch.Size([1])
# 2011 torch.Size([3, 150, 150]) torch.Size([1])
# 2012 torch.Size([3, 150, 150]) torch.Size([1])
# 2013 torch.Size([3, 150, 150]) torch.Size([1])
# 2014 torch.Size([3, 150, 150]) torch.Size([1])
# 2015 torch.Size([3, 150, 150]) torch.Size([1])
# 2016 torch.Size([3, 150, 150]) torch.Size([1])
# 2017 torch.Size([3, 150, 150]) torch.Size([1])
# 2018 torch.Size([3, 150, 150]) torch.Size([1])
# 2019 torch.Size([3, 150, 150]) torch.Size([1])
# 2020 torch.Size([3, 150, 150]) torch.Size([1])
# 2021 torch.Size([3, 150, 150]) torch.Size([1])
# 2022 torch.Size([3, 150, 150]) torch.Size([1])
# 2023 torch.Size([3, 150, 150]) torch.Size([1])
# 2024 torch.Size([3, 150, 150]) torch.Size([1])
# 2025 torch.Size([3, 150, 150]) torch.Size([1])
# 2026 torch.Size([3, 150, 150]) torch.Size([1])
# 2027 torch.Size([3, 150, 150]) torch.Size([1])
# 2028 torch.Size([3, 150, 150]) torch.Size([1])
# 2029 torch.Size([3, 150, 150]) torch.Size([1])
# 2030 torch.Size([3, 150, 150]) torch.Size([1])
# 2031 torch.Size([3, 150, 150]) torch.Size([1])
# 2032 torch.Size([3, 150, 150]) torch.Size([1])
# 2033 torch.Size([3, 150, 150]) torch.Size([1])
# 2034 torch.Size([3, 150, 150]) torch.Size([1])
# 2035 torch.Size([3, 150, 150]) torch.Size([1])
# 2036 torch.Size([3, 150, 150]) torch.Size([1])
# 2037 torch.Size([3, 150, 150]) torch.Size([1])
# 2038 torch.Size([3, 150, 150]) torch.Size([1])
# 2039 torch.Size([3, 150, 150]) torch.Size([1])
# 2040 torch.Size([3, 150, 150]) torch.Size([1])
# 2041 torch.Size([3, 150, 150]) torch.Size([1])
# 2042 torch.Size([3, 150, 150]) torch.Size([1])
# 2043 torch.Size([3, 150, 150]) torch.Size([1])
# 2044 torch.Size([3, 150, 150]) torch.Size([1])
# 2045 torch.Size([3, 150, 150]) torch.Size([1])
# 2046 torch.Size([3, 150, 150]) torch.Size([1])
# 2047 torch.Size([3, 150, 150]) torch.Size([1])
# 2048 torch.Size([3, 150, 150]) torch.Size([1])
# 2049 torch.Size([3, 150, 150]) torch.Size([1])
# 2050 torch.Size([3, 150, 150]) torch.Size([1])
# 2051 torch.Size([3, 150, 150]) torch.Size([1])
# 2052 torch.Size([3, 150, 150]) torch.Size([1])
# 2053 torch.Size([3, 150, 150]) torch.Size([1])
# 2054 torch.Size([3, 150, 150]) torch.Size([1])
# 2055 torch.Size([3, 150, 150]) torch.Size([1])
# 2056 torch.Size([3, 150, 150]) torch.Size([1])
# 2057 torch.Size([3, 150, 150]) torch.Size([1])
# 2058 torch.Size([3, 150, 150]) torch.Size([1])
# 2059 torch.Size([3, 150, 150]) torch.Size([1])
# 2060 torch.Size([3, 150, 150]) torch.Size([1])
# 2061 torch.Size([3, 150, 150]) torch.Size([1])
# 2062 torch.Size([3, 150, 150]) torch.Size([1])
# 2063 torch.Size([3, 150, 150]) torch.Size([1])
# 2064 torch.Size([3, 150, 150]) torch.Size([1])
# 2065 torch.Size([3, 150, 150]) torch.Size([1])
# 2066 torch.Size([3, 150, 150]) torch.Size([1])
# 2067 torch.Size([3, 150, 150]) torch.Size([1])
# 2068 torch.Size([3, 150, 150]) torch.Size([1])
# 2069 torch.Size([3, 150, 150]) torch.Size([1])
# 2070 torch.Size([3, 150, 150]) torch.Size([1])
# 2071 torch.Size([3, 150, 150]) torch.Size([1])
# 2072 torch.Size([3, 150, 150]) torch.Size([1])
# 2073 torch.Size([3, 150, 150]) torch.Size([1])
# 2074 torch.Size([3, 150, 150]) torch.Size([1])
# 2075 torch.Size([3, 150, 150]) torch.Size([1])
# 2076 torch.Size([3, 150, 150]) torch.Size([1])
# 2077 torch.Size([3, 150, 150]) torch.Size([1])
# 2078 torch.Size([3, 150, 150]) torch.Size([1])
# 2079 torch.Size([3, 150, 150]) torch.Size([1])
# 2080 torch.Size([3, 150, 150]) torch.Size([1])
# 2081 torch.Size([3, 150, 150]) torch.Size([1])
# 2082 torch.Size([3, 150, 150]) torch.Size([1])
# 2083 torch.Size([3, 150, 150]) torch.Size([1])
# 2084 torch.Size([3, 150, 150]) torch.Size([1])
# 2085 torch.Size([3, 150, 150]) torch.Size([1])
# 2086 torch.Size([3, 150, 150]) torch.Size([1])
# 2087 torch.Size([3, 150, 150]) torch.Size([1])
# 2088 torch.Size([3, 150, 150]) torch.Size([1])
# 2089 torch.Size([3, 150, 150]) torch.Size([1])
# 2090 torch.Size([3, 150, 150]) torch.Size([1])
# 2091 torch.Size([3, 150, 150]) torch.Size([1])
# 2092 torch.Size([3, 150, 150]) torch.Size([1])
# 2093 torch.Size([3, 150, 150]) torch.Size([1])
# 2094 torch.Size([3, 150, 150]) torch.Size([1])
# 2095 torch.Size([3, 150, 150]) torch.Size([1])
# 2096 torch.Size([3, 150, 150]) torch.Size([1])
# 2097 torch.Size([3, 150, 150]) torch.Size([1])
# 2098 torch.Size([3, 150, 150]) torch.Size([1])
# 2099 torch.Size([3, 150, 150]) torch.Size([1])
# 2100 torch.Size([3, 150, 150]) torch.Size([1])
# 2101 torch.Size([3, 150, 150]) torch.Size([1])
# 2102 torch.Size([3, 150, 150]) torch.Size([1])
# 2103 torch.Size([3, 150, 150]) torch.Size([1])
# 2104 torch.Size([3, 150, 150]) torch.Size([1])
# 2105 torch.Size([3, 150, 150]) torch.Size([1])
# 2106 torch.Size([3, 150, 150]) torch.Size([1])
# 2107 torch.Size([3, 150, 150]) torch.Size([1])
# 2108 torch.Size([3, 150, 150]) torch.Size([1])
# 2109 torch.Size([3, 150, 150]) torch.Size([1])
# 2110 torch.Size([3, 150, 150]) torch.Size([1])
# 2111 torch.Size([3, 150, 150]) torch.Size([1])
# 2112 torch.Size([3, 150, 150]) torch.Size([1])
# 2113 torch.Size([3, 150, 150]) torch.Size([1])
# 2114 torch.Size([3, 150, 150]) torch.Size([1])
# 2115 torch.Size([3, 150, 150]) torch.Size([1])
# 2116 torch.Size([3, 150, 150]) torch.Size([1])
# 2117 torch.Size([3, 150, 150]) torch.Size([1])
# 2118 torch.Size([3, 150, 150]) torch.Size([1])
# 2119 torch.Size([3, 150, 150]) torch.Size([1])
# 2120 torch.Size([3, 150, 150]) torch.Size([1])
# 2121 torch.Size([3, 150, 150]) torch.Size([1])
# 2122 torch.Size([3, 150, 150]) torch.Size([1])
# 2123 torch.Size([3, 150, 150]) torch.Size([1])
# 2124 torch.Size([3, 150, 150]) torch.Size([1])
# 2125 torch.Size([3, 150, 150]) torch.Size([1])
# 2126 torch.Size([3, 150, 150]) torch.Size([1])
# 2127 torch.Size([3, 150, 150]) torch.Size([1])
# 2128 torch.Size([3, 150, 150]) torch.Size([1])
# 2129 torch.Size([3, 150, 150]) torch.Size([1])
# 2130 torch.Size([3, 150, 150]) torch.Size([1])
# 2131 torch.Size([3, 150, 150]) torch.Size([1])
# 2132 torch.Size([3, 150, 150]) torch.Size([1])
# 2133 torch.Size([3, 150, 150]) torch.Size([1])
# 2134 torch.Size([3, 150, 150]) torch.Size([1])
# 2135 torch.Size([3, 150, 150]) torch.Size([1])
# 2136 torch.Size([3, 150, 150]) torch.Size([1])
# 2137 torch.Size([3, 150, 150]) torch.Size([1])
# 2138 torch.Size([3, 150, 150]) torch.Size([1])
# 2139 torch.Size([3, 150, 150]) torch.Size([1])
# 2140 torch.Size([3, 150, 150]) torch.Size([1])
# 2141 torch.Size([3, 150, 150]) torch.Size([1])
# 2142 torch.Size([3, 150, 150]) torch.Size([1])
# 2143 torch.Size([3, 150, 150]) torch.Size([1])
# 2144 torch.Size([3, 150, 150]) torch.Size([1])
# 2145 torch.Size([3, 150, 150]) torch.Size([1])
# 2146 torch.Size([3, 150, 150]) torch.Size([1])
# 2147 torch.Size([3, 150, 150]) torch.Size([1])
# 2148 torch.Size([3, 150, 150]) torch.Size([1])
# 2149 torch.Size([3, 150, 150]) torch.Size([1])
# 2150 torch.Size([3, 150, 150]) torch.Size([1])
# 2151 torch.Size([3, 150, 150]) torch.Size([1])
# 2152 torch.Size([3, 150, 150]) torch.Size([1])
# 2153 torch.Size([3, 150, 150]) torch.Size([1])
# 2154 torch.Size([3, 150, 150]) torch.Size([1])
# 2155 torch.Size([3, 150, 150]) torch.Size([1])
# 2156 torch.Size([3, 150, 150]) torch.Size([1])
# 2157 torch.Size([3, 150, 150]) torch.Size([1])
# 2158 torch.Size([3, 150, 150]) torch.Size([1])
# 2159 torch.Size([3, 150, 150]) torch.Size([1])
# 2160 torch.Size([3, 150, 150]) torch.Size([1])
# 2161 torch.Size([3, 150, 150]) torch.Size([1])
# 2162 torch.Size([3, 150, 150]) torch.Size([1])
# 2163 torch.Size([3, 150, 150]) torch.Size([1])
# 2164 torch.Size([3, 150, 150]) torch.Size([1])
# 2165 torch.Size([3, 150, 150]) torch.Size([1])
# 2166 torch.Size([3, 150, 150]) torch.Size([1])
# 2167 torch.Size([3, 150, 150]) torch.Size([1])
# 2168 torch.Size([3, 150, 150]) torch.Size([1])
# 2169 torch.Size([3, 150, 150]) torch.Size([1])
# 2170 torch.Size([3, 150, 150]) torch.Size([1])
# 2171 torch.Size([3, 150, 150]) torch.Size([1])
# 2172 torch.Size([3, 150, 150]) torch.Size([1])
# 2173 torch.Size([3, 150, 150]) torch.Size([1])
# 2174 torch.Size([3, 150, 150]) torch.Size([1])
# 2175 torch.Size([3, 150, 150]) torch.Size([1])
# 2176 torch.Size([3, 150, 150]) torch.Size([1])
# 2177 torch.Size([3, 150, 150]) torch.Size([1])
# 2178 torch.Size([3, 150, 150]) torch.Size([1])
# 2179 torch.Size([3, 150, 150]) torch.Size([1])
# 2180 torch.Size([3, 150, 150]) torch.Size([1])
# 2181 torch.Size([3, 150, 150]) torch.Size([1])
# 2182 torch.Size([3, 150, 150]) torch.Size([1])
# 2183 torch.Size([3, 150, 150]) torch.Size([1])
# 2184 torch.Size([3, 150, 150]) torch.Size([1])
# 2185 torch.Size([3, 150, 150]) torch.Size([1])
# 2186 torch.Size([3, 150, 150]) torch.Size([1])
# 2187 torch.Size([3, 150, 150]) torch.Size([1])
# 2188 torch.Size([3, 150, 150]) torch.Size([1])
# 2189 torch.Size([3, 150, 150]) torch.Size([1])
# 2190 torch.Size([3, 150, 150]) torch.Size([1])
# 2191 torch.Size([3, 150, 150]) torch.Size([1])
# 2192 torch.Size([3, 150, 150]) torch.Size([1])
# 2193 torch.Size([3, 150, 150]) torch.Size([1])
# 2194 torch.Size([3, 150, 150]) torch.Size([1])
# 2195 torch.Size([3, 150, 150]) torch.Size([1])
# 2196 torch.Size([3, 150, 150]) torch.Size([1])
# 2197 torch.Size([3, 150, 150]) torch.Size([1])
# 2198 torch.Size([3, 150, 150]) torch.Size([1])
# 2199 torch.Size([3, 150, 150]) torch.Size([1])
# 2200 torch.Size([3, 150, 150]) torch.Size([1])
# 2201 torch.Size([3, 150, 150]) torch.Size([1])
# 2202 torch.Size([3, 150, 150]) torch.Size([1])
# 2203 torch.Size([3, 150, 150]) torch.Size([1])
# 2204 torch.Size([3, 150, 150]) torch.Size([1])
# 2205 torch.Size([3, 150, 150]) torch.Size([1])
# 2206 torch.Size([3, 150, 150]) torch.Size([1])
# 2207 torch.Size([3, 150, 150]) torch.Size([1])
# 2208 torch.Size([3, 150, 150]) torch.Size([1])
# 2209 torch.Size([3, 150, 150]) torch.Size([1])
# 2210 torch.Size([3, 150, 150]) torch.Size([1])
# 2211 torch.Size([3, 150, 150]) torch.Size([1])
# 2212 torch.Size([3, 150, 150]) torch.Size([1])
# 2213 torch.Size([3, 150, 150]) torch.Size([1])
# 2214 torch.Size([3, 150, 150]) torch.Size([1])
# 2215 torch.Size([3, 150, 150]) torch.Size([1])
# 2216 torch.Size([3, 150, 150]) torch.Size([1])

# %%
## show a small portation of image
for i in range(len(transformed_dataset)):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['label'].size())

    if i == 3:
        break

# %%
BATCH_SIZE = 2
NUM_WORKERS = 2

train_loader = DataLoader(transformed_dataset, batch_size=BATCH_SIZE, \
                    sampler=sampler.SubsetRandomSampler(range(2000)),\
                    num_workers=NUM_WORKERS)
validation_loader = DataLoader(transformed_dataset, batch_size=BATCH_SIZE,
                    sampler=sampler.SubsetRandomSampler(range(2000,2600)),\
                    num_workers=NUM_WORKERS)

# %% [markdown]
# Now, create a similar `test_generator` for the test data.

# %%
for i_batch, sample_batched in enumerate(train_loader):
    print(i_batch, sample_batched['image'].size(), \
          sample_batched['label'].size())
    # observe 4th batch and stop.
    if i_batch == 3:
        break

# %%
# TODO
# test_generator = ...

# %% [markdown]
# The following function displays images that will be useful below.

# %%
# Display the image

# %% [markdown]
# To see how the `train_generator` works, use the `train_generator.next()` method to get a minibatch of data `X,y`.  Display the first 8 images in this mini-batch and label the image with the class label.  You should see that bicycles have `y=0` and cars have `y=1`.

# %%
# TODO

# %% [markdown]
# ## Train the Model
#
# Compile the model.  Select the correct `loss` function, `optimizer` and `metrics`.  Remember that we are performing binary classification.

# %%
# TODO.
# model.compile(...)

# %% [markdown]
# When using an `ImageDataGenerator`, we have to set two parameters manually:
# * `steps_per_epoch =  training data size // batch_size`
# * `validation_steps =  test data size // batch_size`
#
# We can obtain the training and test data size from `train_generator.n` and `test_generator.n`, respectively.

# %%
# TODO

# %% [markdown]
# Now, we run the fit.  If you are using a CPU on a regular laptop, each epoch will take about 3-4 minutes, so you should be able to finish 5 epochs or so within 20 minutes.  On a reasonable GPU, even with the larger images, it will take about 10 seconds per epoch.
# * If you use `(nrow,ncol) = (64,64)` images, you should get around 90% accuracy after 5 epochs.
# * If you use `(nrow,ncol) = (150,150)` images, you should get around 96% accuracy after 5 epochs.  But, this will need a GPU.
#
# You will get full credit for either version.  With more epochs, you may get slightly higher, but you will have to play with the damping.
#
# Remember to record the history of the fit, so that you can plot the training and validation accuracy curve.

# %%
nepochs = 5  # Number of epochs

# Call the fit_generator function
hist = model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=nepochs,
    validation_data=test_generator,
    validation_steps=validation_steps)

# %%
# Plot the training accuracy and validation accuracy curves on the same figure.

# TO DO

# %% [markdown]
# ## Plotting the Error Images
#
# Now try to plot some images that were in error:
#
# *  Generate a mini-batch `Xts,yts` from the `test_generator.next()` method
# *  Get the class probabilities using the `model.predict( )` method and compute predicted labels `yhat`.
# *  Get the images where `yts[i] ~= yhat[i]`.
# *  If you did not get any prediction error in one minibatch, run it multiple times.
# *  After you a get a few error images (say 4-8), plot the error images with the true labels and class probabilities predicted by the classifie

# %%
# TO DO
